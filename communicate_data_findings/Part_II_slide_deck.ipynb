# %% [markdown]
# # Communicate Data Findings
#
# ## Introduction
#
# > * This project is an analysis into farmer's data to investigate drivers of yield at different stages of the farming process.
#
#
# ### Data Description
#
# > The data is a 3-worksheet `.xlsx file` consisting of 3 worksheets, namely:
# > * **box_placement:**
# > * **wet_harvest:**
# > * **dry_harvest:**
#
# > The data has been gathered to an xlsx spreadsheet and therefore we proceed to assessment, cleaning, and analysis.
#
# *  * **Assumptions**
#
# > * Dry weight of wheat is about 85.7% of wet weight, by the proportion of mean of both wet and dry weights calculation.

# %% [markdown]
# ## Findings of the analysis

# %% [markdown]
# > * We import the required analysis libraries and load the data to the notebook

# %%
# We import all the required libraries to enable analysis in the project.
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
#We define the file path to the excel file we are to use.
xls_path = pd.ExcelFile(r'C:\Users\USER\pula_data_assessment/agricultural_data.xlsx')

# %% [markdown]
# # Assessment stage

# %%
#We load the data from sheet 1 with the data from the box placement forms and view it
box_placement = pd.read_excel(xls_path, 'box_placement')
box_placement.head()
# Out:
#   client_name distance_to_water_body enumerator_comment expected_harvest_date  \
# 0           A                  0-5KM               Done            2022-05-27
# 1           A         More_than_5_KM   successfuly done            2022-05-27
# 2           A         More_than_5_KM                 ok            2022-06-08
# 3           A         More_than_5_KM                 ok            2022-06-06
# 4           A         More_than_5_KM                 ok            2022-06-16
#
#   farmer_in_list_or_control farmer_state_district field_irrigated  \
# 0             farmer_listed               Katsina              no
# 1            control_farmer               Katsina              no
# 2            control_farmer               Zamfara              no
# 3            control_farmer               Zamfara              no
# 4            control_farmer               Zamfara              no
#
#   insured_crop intercropping other_factors_that_affected_germination  ...  \
# 0        wheat            no         insufficient water for watering  ...
# 1        wheat            no                  insufficient watering.  ...
# 2        wheat            no                                    rain  ...
# 3        wheat            no                             soil factor  ...
# 4        wheat            no                             soil factor  ...
#
#   herbicide_applied_box1 box1_cause_of_flood box1_flood_occurence_date  \
# 0                    NaN                 NaN                       NaT
# 1                    NaN                 NaN                       NaT
# 2                    NaN                 NaN                       NaT
# 3                    NaN                 NaN                       NaT
# 4                    NaN                 NaN                       NaT
#
#   box2_flood_occurence_date other_causes_of_weeds_box1  \
# 0                       NaT                        NaN
# 1                       NaT                        NaN
# 2                       NaT                        NaN
# 3                       NaT                        NaN
# 4                       NaT                        NaN
#
#    other_causes_of_weeds_box2   latitude  longitude altitude accuracy
# 0                         NaN  11.367974   7.568032   717.83     6.16
# 1                         NaN  11.367970   7.567983   696.77     4.25
# 2                         NaN  12.046592   6.640337    65.00     1.00
# 3                         NaN  12.046592   6.640337    65.00     3.90
# 4                         NaN  12.051899   6.640011    65.00     1.00
#
# [5 rows x 81 columns]

# %%
#We load the data from sheet 2 with the data from the wet harvest weight forms
wet_harvest = pd.read_excel(xls_path, 'wet_harvest')
wet_harvest.head()
# Out:
#                                @case_id box1_harvest_possible  \
# 0  9d1a878b-ea56-423a-83a5-dce4eee21302                   yes
# 1  ebf9955c-d21e-434a-80d7-658a2cecd0bf                   yes
# 2  eb5f0cf1-0814-48af-94be-62b5dc2524a9                   yes
# 3  79880c35-bb12-4089-8f06-3927b6c44875                   yes
# 4  5d8d55c6-9514-495f-a629-21fd17b92c77                   yes
#
#   box2_harvest_possible enumerator_comment  farmer_verified  box1_wet_weight  \
# 0                   yes                 ok  farmer_verified            3.375
# 1                   yes                 ok  farmer_verified            1.765
# 2                   yes                 ok  farmer_verified            2.920
# 3                   yes                 ok  farmer_verified            2.835
# 4                   yes                 ok  farmer_verified            3.215
#
#    box1_wet_weight_confirmation  box2_wet_weight  \
# 0                         3.375            3.250
# 1                         1.765            1.825
# 2                         2.920            2.835
# 3                         2.835            2.640
# 4                         3.215            3.315
#
#    box2_wet_weight_confirmation                      timeEnd  ...  \
# 0                         3.250  2022-06-04T10:26:17.390000Z  ...
# 1                         1.825  2022-06-04T10:13:45.347000Z  ...
# 2                         2.835  2022-06-04T09:53:46.136000Z  ...
# 3                         2.640  2022-06-04T09:23:13.166000Z  ...
# 4                         3.315  2022-06-04T10:26:42.456000Z  ...
#
#   box_2_non_compliance_confirmation why_unable_to_capture_box2_weight  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   why_no_crop_survived_in_box1 why_no_crop_survived_in_box2 username  \
# 0                          NaN                          NaN   nig040
# 1                          NaN                          NaN   nig040
# 2                          NaN                          NaN   nig040
# 3                          NaN                          NaN   nig040
# 4                          NaN                          NaN   nig040
#
#   wet_harvest_comment   latitude longitude altitude accuracy
# 0                  ok  12.138754  6.686328    107.0     1.26
# 1                  ok  12.138754  6.686328    107.0     1.22
# 2                  ok  12.138754  6.686328    107.0     1.69
# 3                  ok  12.138754  6.686328    107.0     1.64
# 4                  ok  12.138754  6.686328    107.0     1.48
#
# [5 rows x 24 columns]

# %%
#We load the data from sheet 3 with the data from the dry harvest weight forms
dry_harvest = pd.read_excel(xls_path, 'dry_harvest')
dry_harvest.head(3)
# Out:
#                                @case_id  \
# 0  9d1a878b-ea56-423a-83a5-dce4eee21302
# 1  ebf9955c-d21e-434a-80d7-658a2cecd0bf
# 2  eb5f0cf1-0814-48af-94be-62b5dc2524a9
#
#   did_the_farmer_keep_the_crops_in_separate_bags enumerator_comment  \
# 0                                            yes                 ok
# 1                                            yes                 ok
# 2                                            yes                 ok
#
#    farmer_verified  box1_dry_weight  box1_dry_weight_confirmation  \
# 0  farmer_verified            3.250                         3.250
# 1  farmer_verified            1.660                         1.660
# 2  farmer_verified            2.805                         2.805
#
#    box2_dry_weight  box2_dry_weight_confirmation  \
# 0            3.150                         3.150
# 1            1.735                         1.735
# 2            2.770                         2.770
#
#   was_anything_added_or_removed_from_the_harvest_bag  \
# 0                                                 no
# 1                                                 no
# 2                                                 no
#
#                        timeEnd                    timeStart  \
# 0  2022-06-04T10:29:47.353000Z  2022-06-04T10:26:43.768000Z
# 1  2022-06-04T10:21:12.662000Z  2022-06-04T10:13:51.524000Z
# 2  2022-06-04T09:56:59.356000Z  2022-06-04T09:53:54.372000Z
#
#   cannot_proceed_with_dry_harvest username dry_harvest_comment   latitude  \
# 0                             NaN   nig040                  ok  12.138754
# 1                             NaN   nig040                  ok  12.138754
# 2                             NaN   nig040                  ok  12.138754
#
#    longitude  altitude  accuracy
# 0   6.686328     107.0      1.27
# 1   6.686328     107.0      1.57
# 2   6.686328     107.0      1.24

# %% [markdown]
# ## Datasets Merger:
#
# > > * We merge the datasets to use in our analysis

# %%
# We do a union merger of the box_placement and wet_harvest datasets on the @case_id and add suffixes _box and _wet for columns with commin values
box_and_wet = pd.merge(box_placement,wet_harvest,on = '@case_id',how = 'outer',suffixes = ('_box','_wet'))
box_and_wet.shape
# Out:
# (2356, 104)

# %%
box_and_wet.head(4)
# Out:
#   client_name distance_to_water_body enumerator_comment_box  \
# 0           A                  0-5KM                   Done
# 1           A         More_than_5_KM       successfuly done
# 2           A         More_than_5_KM                     ok
# 3           A         More_than_5_KM                     ok
#
#   expected_harvest_date farmer_in_list_or_control farmer_state_district  \
# 0            2022-05-27             farmer_listed               Katsina
# 1            2022-05-27            control_farmer               Katsina
# 2            2022-06-08            control_farmer               Zamfara
# 3            2022-06-06            control_farmer               Zamfara
#
#   field_irrigated insured_crop intercropping  \
# 0              no        wheat            no
# 1              no        wheat            no
# 2              no        wheat            no
# 3              no        wheat            no
#
#   other_factors_that_affected_germination  ...  \
# 0         insufficient water for watering  ...
# 1                  insufficient watering.  ...
# 2                                    rain  ...
# 3                             soil factor  ...
#
#   box_2_non_compliance_confirmation why_unable_to_capture_box2_weight  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
#
#   why_no_crop_survived_in_box1 why_no_crop_survived_in_box2 username_wet  \
# 0                          NaN                          NaN       nig187
# 1                          NaN                          NaN       nig187
# 2                          NaN                          NaN       nig040
# 3                          NaN                          NaN       nig040
#
#    wet_harvest_comment latitude_wet  longitude_wet altitude_wet accuracy_wet
# 0                 Done    11.367886       7.568027       694.28         4.73
# 1                 Done    11.368021       7.568042       712.78         3.90
# 2                   ok    12.147570       6.714653       107.00         1.51
# 3                   ok    12.138754       6.686328       107.00         1.21
#
# [4 rows x 104 columns]

# %%
# We do a union merge of the dry harvest data form and the data containing box placement 
box_and_wet_and_dry = pd.merge(box_and_wet,dry_harvest,on = '@case_id',how = 'outer')
box_and_wet_and_dry.shape
# Out:
# (2356, 121)

# %%
# We use code to view if the merge was successful
box_and_wet_and_dry.head(4)
# Out:
#   client_name distance_to_water_body enumerator_comment_box  \
# 0           A                  0-5KM                   Done
# 1           A         More_than_5_KM       successfuly done
# 2           A         More_than_5_KM                     ok
# 3           A         More_than_5_KM                     ok
#
#   expected_harvest_date farmer_in_list_or_control farmer_state_district  \
# 0            2022-05-27             farmer_listed               Katsina
# 1            2022-05-27            control_farmer               Katsina
# 2            2022-06-08            control_farmer               Zamfara
# 3            2022-06-06            control_farmer               Zamfara
#
#   field_irrigated insured_crop intercropping  \
# 0              no        wheat            no
# 1              no        wheat            no
# 2              no        wheat            no
# 3              no        wheat            no
#
#   other_factors_that_affected_germination  ...  \
# 0         insufficient water for watering  ...
# 1                  insufficient watering.  ...
# 2                                    rain  ...
# 3                             soil factor  ...
#
#   was_anything_added_or_removed_from_the_harvest_bag  \
# 0                                                NaN
# 1                                                 no
# 2                                                 no
# 3                                                 no
#
#                        timeEnd                    timeStart  \
# 0                          NaN                          NaN
# 1  2022-05-27T11:09:45.357000Z  2022-05-27T10:56:36.195000Z
# 2  2022-06-01T11:25:45.374000Z  2022-06-01T11:18:01.603000Z
# 3  2022-06-01T10:41:21.419000Z  2022-06-01T10:36:22.089000Z
#
#   cannot_proceed_with_dry_harvest username  dry_harvest_comment   latitude  \
# 0                             NaN      NaN                  NaN        NaN
# 1                             NaN   nig187                 Done  11.368059
# 2                             NaN   nig040                   ok  12.147570
# 3                             NaN   nig040                   ok  12.138754
#
#    longitude altitude accuracy
# 0        NaN      NaN      NaN
# 1   7.568079   721.23     8.00
# 2   6.714653   107.00     1.49
# 3   6.686328   107.00     1.47
#
# [4 rows x 121 columns]

# %%
#we rename the box_and_wet_and_dry data as raw_crop_merged_data
raw_crop_merged_data = box_and_wet_and_dry

# %%
#create a merged data frame
merged_data = raw_crop_merged_data
merged_data.head(4)
# Out:
#   client_name distance_to_water_body enumerator_comment_box  \
# 0           A                  0-5KM                   Done
# 1           A         More_than_5_KM       successfuly done
# 2           A         More_than_5_KM                     ok
# 3           A         More_than_5_KM                     ok
#
#   expected_harvest_date farmer_in_list_or_control farmer_state_district  \
# 0            2022-05-27             farmer_listed               Katsina
# 1            2022-05-27            control_farmer               Katsina
# 2            2022-06-08            control_farmer               Zamfara
# 3            2022-06-06            control_farmer               Zamfara
#
#   field_irrigated insured_crop intercropping  \
# 0              no        wheat            no
# 1              no        wheat            no
# 2              no        wheat            no
# 3              no        wheat            no
#
#   other_factors_that_affected_germination  ...  \
# 0         insufficient water for watering  ...
# 1                  insufficient watering.  ...
# 2                                    rain  ...
# 3                             soil factor  ...
#
#   was_anything_added_or_removed_from_the_harvest_bag  \
# 0                                                NaN
# 1                                                 no
# 2                                                 no
# 3                                                 no
#
#                        timeEnd                    timeStart  \
# 0                          NaN                          NaN
# 1  2022-05-27T11:09:45.357000Z  2022-05-27T10:56:36.195000Z
# 2  2022-06-01T11:25:45.374000Z  2022-06-01T11:18:01.603000Z
# 3  2022-06-01T10:41:21.419000Z  2022-06-01T10:36:22.089000Z
#
#   cannot_proceed_with_dry_harvest username  dry_harvest_comment   latitude  \
# 0                             NaN      NaN                  NaN        NaN
# 1                             NaN   nig187                 Done  11.368059
# 2                             NaN   nig040                   ok  12.147570
# 3                             NaN   nig040                   ok  12.138754
#
#    longitude altitude accuracy
# 0        NaN      NaN      NaN
# 1   7.568079   721.23     8.00
# 2   6.714653   107.00     1.49
# 3   6.686328   107.00     1.47
#
# [4 rows x 121 columns]

# %% [markdown]
# ## Selection of columns to analyze:
#
# > Due to the nature of the dataset, we index columns relevant to the goal of the analysis.

# %%
#We use code to view the 1st 100 column names
merged_data.columns[:100]
# Out:
# Index(['client_name', 'distance_to_water_body', 'enumerator_comment_box',
#        'expected_harvest_date', 'farmer_in_list_or_control',
#        'farmer_state_district', 'field_irrigated', 'insured_crop',
#        'intercropping', 'other_factors_that_affected_germination',
#        'planting_date', 'success_box1', 'success_box2',
#        'ward_lga_subcounty_camp', 'box1_crop_condition',
#        'box1_crop_stands_per_square_meter', 'box1_dim_8_by_5', 'box1_length',
#        'box1_mode_of_planting', 'box1_other_issues_occurrence_date',
#        'box1_other_problems', 'box1_problem', 'box1_secondary_issues',
#        'box1_width', 'box2_crop_condition',
#        'box2_crop_stands_per_square_meter', 'box2_dim_8_by_5', 'box2_length',
#        'box2_mode_of_planting', 'box2_other_issues_occurrence_date',
#        'box2_other_problems', 'box2_problem', 'box2_secondary_issues',
#        'box2_width', '@case_id', 'timeEnd_box', 'timeStart_box',
#        'type_of_pests_or_diseases_current_crop_stage',
#        'what_steps_did_the_farmer_take_to_mitigate_the_pests_or_diseases',
#        'why_unable_to_place_box1', 'type_of_irrigation_system', 'box1_rows',
#        'measurement_box1_row1', 'measurement_box1_row2',
#        'measurement_box1_row3', 'box2_rows', 'measurement_box2_row1',
#        'measurement_box2_row2', 'measurement_box2_row3',
#        'box1_drought_occurence_date', 'box1_locust_infestation_date',
#        'box2_drought_occurence_date', 'box2_locust_infestation_date',
#        'box1_other_pest_disease_occurence_date',
#        'box1_pests_or_diseases_mitigation', 'box1_type_of_pests_or_diseases',
#        'box2_other_pest_disease_occurence_date',
#        'box2_pests_and_diseases_mitigation', 'box2_type_of_pests_or_diseases',
#        'how_is_the_other_crop_planted', 'other_crops_names',
#        'box1_animal_encroachment_date', 'box2_animal_encroachment_date',
#        'causes_of_weeds_box2', 'weeds_mitigation_box2',
#        'other_crops_not_listed', 'causes_of_weeds_box1',
#        'weeds_mitigation_box1', 'why_unable_to_place_box2', 'username_box',
#        'box_placement_comment', 'herbicide_applied_box1',
#        'box1_cause_of_flood', 'box1_flood_occurence_date',
#        'box2_flood_occurence_date', 'other_causes_of_weeds_box1',
#        'other_causes_of_weeds_box2', 'latitude_box', 'longitude_box',
#        'altitude_box', 'accuracy_box', 'box1_harvest_possible',
#        'box2_harvest_possible', 'enumerator_comment_wet', 'farmer_verified_x',
#        'box1_wet_weight', 'box1_wet_weight_confirmation', 'box2_wet_weight',
#        'box2_wet_weight_confirmation', 'timeEnd_wet', 'timeStart_wet',
#        'cannot_proceed_with_wet_harvest', 'box_1_non_compliance_confirmation',
#        'why_unable_to_capture_box1_weight',
#        'box_2_non_compliance_confirmation',
#        'why_unable_to_capture_box2_weight', 'why_no_crop_survived_in_box1',
#        'why_no_crop_survived_in_box2', 'username_wet', 'wet_harvest_comment'],
#       dtype='object')

# %%
#We use code to view the remaining columns of the data
merged_data.columns[99:]
# Out:
# Index(['wet_harvest_comment', 'latitude_wet', 'longitude_wet', 'altitude_wet',
#        'accuracy_wet', 'did_the_farmer_keep_the_crops_in_separate_bags',
#        'enumerator_comment', 'farmer_verified_y', 'box1_dry_weight',
#        'box1_dry_weight_confirmation', 'box2_dry_weight',
#        'box2_dry_weight_confirmation',
#        'was_anything_added_or_removed_from_the_harvest_bag', 'timeEnd',
#        'timeStart', 'cannot_proceed_with_dry_harvest', 'username',
#        'dry_harvest_comment', 'latitude', 'longitude', 'altitude', 'accuracy'],
#       dtype='object')

# %% [markdown]
# ### Listing of all column names:
# > * **all_column_names** = \['client_name', 'distance_to_water_body', 'enumerator_comment_box',
#        'expected_harvest_date', 'farmer_in_list_or_control',
#        'farmer_state_district', 'field_irrigated', 'insured_crop',
#        'intercropping', 'other_factors_that_affected_germination',
#        'planting_date', 'success_box1', 'success_box2',
#        'ward_lga_subcounty_camp', 'box1_crop_condition',
#        'box1_crop_stands_per_square_meter', 'box1_dim_8_by_5', 'box1_length',
#        'box1_mode_of_planting', 'box1_other_issues_occurrence_date',
#        'box1_other_problems', 'box1_problem', 'box1_secondary_issues',
#        'box1_width', 'box2_crop_condition',
#        'box2_crop_stands_per_square_meter', 'box2_dim_8_by_5', 'box2_length',
#        'box2_mode_of_planting', 'box2_other_issues_occurrence_date',
#        'box2_other_problems', 'box2_problem', 'box2_secondary_issues',
#        'box2_width', '@case_id', 'timeEnd_box', 'timeStart_box',
#        'type_of_pests_or_diseases_current_crop_stage',
#        'what_steps_did_the_farmer_take_to_mitigate_the_pests_or_diseases',
#        'why_unable_to_place_box1', 'type_of_irrigation_system', 'box1_rows',
#        'measurement_box1_row1', 'measurement_box1_row2',
#        'measurement_box1_row3', 'box2_rows', 'measurement_box2_row1',
#        'measurement_box2_row2', 'measurement_box2_row3',
#        'box1_drought_occurence_date', 'box1_locust_infestation_date',
#        'box2_drought_occurence_date', 'box2_locust_infestation_date',
#        'box1_other_pest_disease_occurence_date',
#        'box1_pests_or_diseases_mitigation', 'box1_type_of_pests_or_diseases',
#        'box2_other_pest_disease_occurence_date',
#        'box2_pests_and_diseases_mitigation', 'box2_type_of_pests_or_diseases',
#        'how_is_the_other_crop_planted', 'other_crops_names',
#        'box1_animal_encroachment_date', 'box2_animal_encroachment_date',
#        'causes_of_weeds_box2', 'weeds_mitigation_box2',
#        'other_crops_not_listed', 'causes_of_weeds_box1',
#        'weeds_mitigation_box1', 'why_unable_to_place_box2', 'username_box',
#        'box_placement_comment', 'herbicide_applied_box1',
#        'box1_cause_of_flood', 'box1_flood_occurence_date',
#        'box2_flood_occurence_date', 'other_causes_of_weeds_box1',
#        'other_causes_of_weeds_box2', 'latitude_box', 'longitude_box',
#        'altitude_box', 'accuracy_box', 'box1_harvest_possible',
#        'box2_harvest_possible', 'enumerator_comment_wet', 'farmer_verified_x',
#        'box1_wet_weight', 'box1_wet_weight_confirmation', 'box2_wet_weight',
#        'box2_wet_weight_confirmation', 'timeEnd_wet', 'timeStart_wet',
#        'cannot_proceed_with_wet_harvest', 'box_1_non_compliance_confirmation',
#        'why_unable_to_capture_box1_weight',
#        'box_2_non_compliance_confirmation',
#        'why_unable_to_capture_box2_weight', 'why_no_crop_survived_in_box1',
#        'why_no_crop_survived_in_box2', 'username_wet', 'wet_harvest_comment','latitude_wet', 'longitude_wet', 'altitude_wet',
#        'accuracy_wet', 'did_the_farmer_keep_the_crops_in_separate_bags',
#        'enumerator_comment', 'farmer_verified_y', 'box1_dry_weight',
#        'box1_dry_weight_confirmation', 'box2_dry_weight',
#        'box2_dry_weight_confirmation',
#        'was_anything_added_or_removed_from_the_harvest_bag', 'timeEnd',
#        'timeStart', 'cannot_proceed_with_dry_harvest', 'username',
#        'dry_harvest_comment', 'latitude', 'longitude', 'altitude', 'accuracy']

# %% [markdown]
# ### Subset columns:
#
# > > * In our analysis, we seek to investigate the factors that affect the yield. Inthat, we seek to choose the most relevant yield drivers.
#
# > > * **relevant_columns** =  \['client_name', 'distance_to_water_body', 'farmer_in_list_or_control',
#        'farmer_state_district', 'field_irrigated', 'insured_crop', 'intercropping', 'box1_mode_of_planting','box2_mode_of_planting',
#        '@case_id', 'type_of_pests_or_diseases_current_crop_stage',
#        'what_steps_did_the_farmer_take_to_mitigate_the_pests_or_diseases',
#        'type_of_irrigation_system', 'other_crops_names', 'username_box', 'herbicide_applied_box1', 'latitude_box',    'longitude_box', 'altitude_box', 'accuracy_box', 'box1_wet_weight', 'box1_wet_weight_confirmation', 'box2_wet_weight',      'box2_wet_weight_confirmation', 'username_wet', 'latitude_wet', 'longitude_wet', 'altitude_wet',
#        'accuracy_wet', 'did_the_farmer_keep_the_crops_in_separate_bags', 'farmer_verified_y', 'box1_dry_weight', 'box1_dry_weight_confirmation', 'box2_dry_weight', 'box2_dry_weight_confirmation', 'latitude', 'longitude', 'altitude', 'accuracy']

# %% [markdown]
# ## Selection of columns and storage: merged_data_to_analyze

# %%
#We use code to select the columns required for analysis
merged_data_to_analyze = merged_data[['client_name', 'distance_to_water_body', 'farmer_in_list_or_control',
                                       'farmer_state_district', 'field_irrigated', 'insured_crop', 
                                      'intercropping', 'box1_mode_of_planting', 'box2_mode_of_planting', '@case_id',
                                      'type_of_irrigation_system', 'other_crops_names', 'username_box', 
                                      'latitude_box',    'longitude_box', 'altitude_box', 
                                      'accuracy_box', 'box1_wet_weight', 'box1_wet_weight_confirmation', 
                                      'box2_wet_weight',      'box2_wet_weight_confirmation', 'username_wet', 
                                      'latitude_wet', 'longitude_wet', 'altitude_wet', 'accuracy_wet', 
                                      'did_the_farmer_keep_the_crops_in_separate_bags', 'farmer_verified_y', 
                                      'box1_dry_weight', 'box1_dry_weight_confirmation', 'box2_dry_weight', 
                                      'box2_dry_weight_confirmation', 'latitude', 'longitude', 'altitude', 'accuracy']]

# %%
#We use code to view the data shape
merged_data_to_analyze.shape
# Out:
# (2356, 36)

# %%
#We use code to view the first lines
merged_data_to_analyze.head()
# Out:
#   client_name distance_to_water_body farmer_in_list_or_control  \
# 0           A                  0-5KM             farmer_listed
# 1           A         More_than_5_KM            control_farmer
# 2           A         More_than_5_KM            control_farmer
# 3           A         More_than_5_KM            control_farmer
# 4           A         More_than_5_KM            control_farmer
#
#   farmer_state_district field_irrigated insured_crop intercropping  \
# 0               Katsina              no        wheat            no
# 1               Katsina              no        wheat            no
# 2               Zamfara              no        wheat            no
# 3               Zamfara              no        wheat            no
# 4               Zamfara              no        wheat            no
#
#   box1_mode_of_planting box2_mode_of_planting  \
# 0           broadcasted           broadcasted
# 1           broadcasted           broadcasted
# 2           broadcasted           broadcasted
# 3           broadcasted           broadcasted
# 4           broadcasted           broadcasted
#
#                                @case_id  ...  \
# 0  b8a79a54-442e-4d79-9656-65af4e6c5733  ...
# 1  36311aa7-29d1-4650-a230-830bcd565d72  ...
# 2  0a9e2724-59e1-48cd-ab48-856dce787fec  ...
# 3  da9f7363-2415-415e-8cef-d6bb18ed2bc0  ...
# 4  9a14fb60-c3a6-4794-9f92-e84953db4b32  ...
#
#   did_the_farmer_keep_the_crops_in_separate_bags farmer_verified_y  \
# 0                                            NaN               NaN
# 1                                            yes   farmer_verified
# 2                                            yes   farmer_verified
# 3                                            yes   farmer_verified
# 4                                            yes   farmer_verified
#
#   box1_dry_weight  box1_dry_weight_confirmation  box2_dry_weight  \
# 0             NaN                           NaN              NaN
# 1           5.630                         5.630            3.760
# 2           2.690                         2.690            2.720
# 3           2.185                         2.185            2.520
# 4           3.155                         3.155            3.135
#
#    box2_dry_weight_confirmation   latitude  longitude  altitude  accuracy
# 0                           NaN        NaN        NaN       NaN       NaN
# 1                         3.760  11.368059   7.568079    721.23      8.00
# 2                         2.720  12.147570   6.714653    107.00      1.49
# 3                         2.520  12.138754   6.686328    107.00      1.47
# 4                         3.135  12.138754   6.686328    107.00      1.48
#
# [5 rows x 36 columns]

# %%
#We use code to view the data types in the dataframe
print(merged_data_to_analyze.dtypes)
# Out:
# client_name                                        object
# distance_to_water_body                             object
# farmer_in_list_or_control                          object
# farmer_state_district                              object
# field_irrigated                                    object
# insured_crop                                       object
# intercropping                                      object
# box1_mode_of_planting                              object
# box2_mode_of_planting                              object
# @case_id                                           object
# type_of_irrigation_system                          object
# other_crops_names                                  object
# username_box                                       object
# latitude_box                                      float64
# longitude_box                                     float64
# altitude_box                                      float64
# accuracy_box                                      float64
# box1_wet_weight                                   float64
# box1_wet_weight_confirmation                      float64
# box2_wet_weight                                   float64
# box2_wet_weight_confirmation                      float64
# username_wet                                       object
# latitude_wet                                      float64
# longitude_wet                                     float64
# altitude_wet                                      float64
# accuracy_wet                                      float64
# did_the_farmer_keep_the_crops_in_separate_bags     object
# farmer_verified_y                                  object
# box1_dry_weight                                   float64
# box1_dry_weight_confirmation                      float64
# box2_dry_weight                                   float64
# box2_dry_weight_confirmation                      float64
# latitude                                          float64
# longitude                                         float64
# altitude                                          float64
# accuracy                                          float64
# dtype: object

# %% [markdown]
# ## What is the structure of your Dataset?
#
# > There are 2356 farmers with 39 characteristics. Most variables are numeric in nature, but farmer district,insured crop,box_1_problem, box2_problem are categorical variables.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > I am interested in figuring out what features are most relevant in predicting yields for different regions.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
# I was thinking that the distance from water body has the highest impact to the yield.

# %% [markdown]
# # Data Assessment

# %%
# We load the focused assessment data.
raw_focused_data = merged_data_to_analyze

# %% [markdown]
# # Visual assessment:
#
# > In this stage we use visual assessment to find quality and tidiness issues with the data.

# %%
# View samples from the data
raw_focused_data.sample(20).T
# Out:
#                                                                                 1531  \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                        Adamawa
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        12ed14b3-d53b-4215-adac-a9666100bc78
# type_of_irrigation_system                                                   borehole
# other_crops_names                                                                NaN
# username_box                                                                  nig176
# latitude_box                                                                9.046849
# longitude_box                                                              12.042121
# altitude_box                                                                   236.3
# accuracy_box                                                                    7.73
# box1_wet_weight                                                                 8.31
# box1_wet_weight_confirmation                                                    8.31
# box2_wet_weight                                                                9.135
# box2_wet_weight_confirmation                                                   9.135
# username_wet                                                                  nig176
# latitude_wet                                                                9.062607
# longitude_wet                                                              12.059016
# altitude_wet                                                                  261.89
# accuracy_wet                                                                    4.25
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 7.58
# box1_dry_weight_confirmation                                                    7.58
# box2_dry_weight                                                                  7.9
# box2_dry_weight_confirmation                                                     7.9
# latitude                                                                    9.062358
# longitude                                                                  12.058865
# altitude                                                                       256.2
# accuracy                                                                        5.21
#
#                                                                                 2288  \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                         Bauchi
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        c323f90a-d0c7-4c88-ae30-ec74b876cd20
# type_of_irrigation_system                                                  tube_well
# other_crops_names                                                                NaN
# username_box                                                                  nig022
# latitude_box                                                               10.432215
# longitude_box                                                               9.857928
# altitude_box                                                                   552.9
# accuracy_box                                                                     3.9
# box1_wet_weight                                                                  6.9
# box1_wet_weight_confirmation                                                     6.9
# box2_wet_weight                                                                 7.06
# box2_wet_weight_confirmation                                                    7.06
# username_wet                                                                  nig022
# latitude_wet                                                                9.975367
# longitude_wet                                                               9.753552
# altitude_wet                                                                   536.0
# accuracy_wet                                                                     7.0
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 4.83
# box1_dry_weight_confirmation                                                    4.83
# box2_dry_weight                                                                5.895
# box2_dry_weight_confirmation                                                   5.895
# latitude                                                                    9.975308
# longitude                                                                   9.753475
# altitude                                                                       536.1
# accuracy                                                                        3.94
#
#                                                                                 1544  \
# client_name                                                                        A
# distance_to_water_body                                                More_than_5_KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                          Borno
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        95562e59-234c-4674-93fd-a84e1c6f8364
# type_of_irrigation_system                                                       well
# other_crops_names                                                                NaN
# username_box                                                                  nig174
# latitude_box                                                               10.174837
# longitude_box                                                              12.040007
# altitude_box                                                                  198.06
# accuracy_box                                                                     3.9
# box1_wet_weight                                                                4.135
# box1_wet_weight_confirmation                                                   4.135
# box2_wet_weight                                                                 4.11
# box2_wet_weight_confirmation                                                    4.11
# username_wet                                                                  nig174
# latitude_wet                                                               10.173163
# longitude_wet                                                              12.043205
# altitude_wet                                                                  191.19
# accuracy_wet                                                                     3.9
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                4.135
# box1_dry_weight_confirmation                                                   4.135
# box2_dry_weight                                                                4.135
# box2_dry_weight_confirmation                                                   4.135
# latitude                                                                    10.17316
# longitude                                                                   12.04319
# altitude                                                                      190.31
# accuracy                                                                         3.9
#
#                                                                                 166   \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                             control_farmer
# farmer_state_district                                                          Kebbi
# field_irrigated                                                                   no
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        6700f334-c1a8-46ed-b807-2fcd86e33a52
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                                NaN
# username_box                                                                  nig109
# latitude_box                                                               11.850083
# longitude_box                                                               3.637207
# altitude_box                                                                    65.0
# accuracy_box                                                                     1.0
# box1_wet_weight                                                                5.075
# box1_wet_weight_confirmation                                                   5.075
# box2_wet_weight                                                                 5.21
# box2_wet_weight_confirmation                                                    5.21
# username_wet                                                                  nig109
# latitude_wet                                                               11.850083
# longitude_wet                                                               3.637207
# altitude_wet                                                                    65.0
# accuracy_wet                                                                     1.0
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                4.295
# box1_dry_weight_confirmation                                                   4.295
# box2_dry_weight                                                                4.155
# box2_dry_weight_confirmation                                                   4.155
# latitude                                                                   11.843226
# longitude                                                                   3.642835
# altitude                                                                        65.0
# accuracy                                                                         1.0
#
#                                                                                 1361  \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                             control_farmer
# farmer_state_district                                                        Zamfara
# field_irrigated                                                                   no
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        f7f3537a-0dbb-4c9e-ac93-0bb151bc5534
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                                NaN
# username_box                                                                  nig038
# latitude_box                                                               12.664492
# longitude_box                                                                5.94867
# altitude_box                                                                   288.6
# accuracy_box                                                                     4.4
# box1_wet_weight                                                                 2.99
# box1_wet_weight_confirmation                                                    2.99
# box2_wet_weight                                                                 3.17
# box2_wet_weight_confirmation                                                    3.17
# username_wet                                                                  nig038
# latitude_wet                                                               12.716583
# longitude_wet                                                               5.873524
# altitude_wet                                                                   107.0
# accuracy_wet                                                                    1.39
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                  2.7
# box1_dry_weight_confirmation                                                     2.7
# box2_dry_weight                                                                2.905
# box2_dry_weight_confirmation                                                   2.905
# latitude                                                                   12.716583
# longitude                                                                   5.873524
# altitude                                                                       107.0
# accuracy                                                                        1.64
#
#                                                                                 2355  \
# client_name                                                                        A
# distance_to_water_body                                                More_than_5_KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                         Bauchi
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        7bb16742-b5fc-4ee0-86cb-93d653eb9150
# type_of_irrigation_system                                                  tube_well
# other_crops_names                                                                NaN
# username_box                                                                  nig022
# latitude_box                                                               10.345544
# longitude_box                                                              10.038725
# altitude_box                                                                   468.4
# accuracy_box                                                                     3.9
# box1_wet_weight                                                                 6.14
# box1_wet_weight_confirmation                                                    6.14
# box2_wet_weight                                                                7.345
# box2_wet_weight_confirmation                                                   7.345
# username_wet                                                                  nig022
# latitude_wet                                                               10.431863
# longitude_wet                                                               9.860139
# altitude_wet                                                                  559.29
# accuracy_wet                                                                    8.42
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                5.445
# box1_dry_weight_confirmation                                                   5.445
# box2_dry_weight                                                                6.425
# box2_dry_weight_confirmation                                                   6.425
# latitude                                                                   10.698528
# longitude                                                                    9.76795
# altitude                                                                      538.29
# accuracy                                                                        3.52
#
#                                                                                 2330  \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                         Bauchi
# field_irrigated                                                                   no
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        ddb19306-7c8d-4e53-8d09-eff8ba87392a
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                                NaN
# username_box                                                                  nig033
# latitude_box                                                               12.119812
# longitude_box                                                               10.26872
# altitude_box                                                                   345.2
# accuracy_box                                                                    4.95
# box1_wet_weight                                                                3.885
# box1_wet_weight_confirmation                                                   3.885
# box2_wet_weight                                                                4.605
# box2_wet_weight_confirmation                                                   4.605
# username_wet                                                                  nig033
# latitude_wet                                                               12.128405
# longitude_wet                                                              10.269293
# altitude_wet                                                                   381.9
# accuracy_wet                                                                     4.5
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 3.25
# box1_dry_weight_confirmation                                                    3.25
# box2_dry_weight                                                                4.325
# box2_dry_weight_confirmation                                                   4.325
# latitude                                                                   12.125778
# longitude                                                                  10.279687
# altitude                                                                       373.6
# accuracy                                                                         4.8
#
#                                                                                 591   \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                             control_farmer
# farmer_state_district                                                         Jigawa
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                            NaN
# box2_mode_of_planting                                                            NaN
# @case_id                                        f05e8683-75a0-44a5-b7ff-1e22b4210459
# type_of_irrigation_system                                                        Dam
# other_crops_names                                                                NaN
# username_box                                                                  nig114
# latitude_box                                                               12.171147
# longitude_box                                                               9.448187
# altitude_box                                                                   368.9
# accuracy_box                                                                    4.16
# box1_wet_weight                                                                  NaN
# box1_wet_weight_confirmation                                                     NaN
# box2_wet_weight                                                                  NaN
# box2_wet_weight_confirmation                                                     NaN
# username_wet                                                                     NaN
# latitude_wet                                                                     NaN
# longitude_wet                                                                    NaN
# altitude_wet                                                                     NaN
# accuracy_wet                                                                     NaN
# did_the_farmer_keep_the_crops_in_separate_bags                                   NaN
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                  NaN
# box1_dry_weight_confirmation                                                     NaN
# box2_dry_weight                                                                  NaN
# box2_dry_weight_confirmation                                                     NaN
# latitude                                                                         NaN
# longitude                                                                        NaN
# altitude                                                                         NaN
# accuracy                                                                         NaN
#
#                                                                                 727   \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                          Gombe
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        e3217168-a3e5-4701-86ab-e2aa32d0370f
# type_of_irrigation_system                                                     rivers
# other_crops_names                                                                NaN
# username_box                                                                  nig048
# latitude_box                                                               10.287905
# longitude_box                                                              11.295079
# altitude_box                                                                   334.5
# accuracy_box                                                                    9.44
# box1_wet_weight                                                                 9.33
# box1_wet_weight_confirmation                                                    9.33
# box2_wet_weight                                                                9.385
# box2_wet_weight_confirmation                                                   9.385
# username_wet                                                                  nig048
# latitude_wet                                                               10.287961
# longitude_wet                                                              11.294903
# altitude_wet                                                                   368.1
# accuracy_wet                                                                    8.52
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                9.265
# box1_dry_weight_confirmation                                                   9.265
# box2_dry_weight                                                                9.385
# box2_dry_weight_confirmation                                                   9.385
# latitude                                                                    10.28791
# longitude                                                                  11.294955
# altitude                                                                       367.8
# accuracy                                                                        3.84
#
#                                                                                 981   \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                          Niger
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        aa6f6c5c-a75f-426f-a347-b40f3a543601
# type_of_irrigation_system                                                     rivers
# other_crops_names                                                                NaN
# username_box                                                                  nig102
# latitude_box                                                                9.531023
# longitude_box                                                               6.586442
# altitude_box                                                                   214.6
# accuracy_box                                                                    4.84
# box1_wet_weight                                                                 1.14
# box1_wet_weight_confirmation                                                    1.14
# box2_wet_weight                                                                 1.09
# box2_wet_weight_confirmation                                                    1.09
# username_wet                                                                  nig102
# latitude_wet                                                                9.635606
# longitude_wet                                                               6.499575
# altitude_wet                                                                   253.8
# accuracy_wet                                                                    4.93
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                0.865
# box1_dry_weight_confirmation                                                   0.865
# box2_dry_weight                                                                0.151
# box2_dry_weight_confirmation                                                   0.151
# latitude                                                                    9.635671
# longitude                                                                   6.499564
# altitude                                                                       232.1
# accuracy                                                                         4.8
#
#                                                                                 1006  \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                             control_farmer
# farmer_state_district                                                        Adamawa
# field_irrigated                                                                   no
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        71411d1d-eaf7-43d9-aa13-667b04385a3a
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                                NaN
# username_box                                                                  nig179
# latitude_box                                                                9.787205
# longitude_box                                                               11.99401
# altitude_box                                                                  204.55
# accuracy_box                                                                    7.55
# box1_wet_weight                                                                  7.0
# box1_wet_weight_confirmation                                                     7.0
# box2_wet_weight                                                                8.135
# box2_wet_weight_confirmation                                                   8.135
# username_wet                                                                  nig179
# latitude_wet                                                                9.832492
# longitude_wet                                                              11.987399
# altitude_wet                                                                  212.75
# accuracy_wet                                                                     4.0
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 6.11
# box1_dry_weight_confirmation                                                    6.11
# box2_dry_weight                                                                6.125
# box2_dry_weight_confirmation                                                   6.125
# latitude                                                                    9.832494
# longitude                                                                  11.987389
# altitude                                                                      214.02
# accuracy                                                                         3.9
#
#                                                                                 991   \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                        Adamawa
# field_irrigated                                                                   no
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        5bd31057-ef82-472f-ab5a-ba4609d06604
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                                NaN
# username_box                                                                  nig179
# latitude_box                                                                 9.83402
# longitude_box                                                              11.988353
# altitude_box                                                                  224.79
# accuracy_box                                                                     2.0
# box1_wet_weight                                                                7.165
# box1_wet_weight_confirmation                                                   7.165
# box2_wet_weight                                                                 8.06
# box2_wet_weight_confirmation                                                    8.06
# username_wet                                                                  nig179
# latitude_wet                                                                9.833049
# longitude_wet                                                              11.987151
# altitude_wet                                                                  220.31
# accuracy_wet                                                                     4.0
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 6.09
# box1_dry_weight_confirmation                                                    6.09
# box2_dry_weight                                                                 5.03
# box2_dry_weight_confirmation                                                    5.03
# latitude                                                                    9.833016
# longitude                                                                  11.987127
# altitude                                                                      224.77
# accuracy                                                                         4.0
#
#                                                                                 917   \
# client_name                                                                        A
# distance_to_water_body                                                More_than_5_KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                           Kano
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        a3714c5e-46a5-4d88-ae27-ffbc3c7549fa
# type_of_irrigation_system                                                  tube_well
# other_crops_names                                                                NaN
# username_box                                                                  nig047
# latitude_box                                                               12.084407
# longitude_box                                                               9.158425
# altitude_box                                                                  417.14
# accuracy_box                                                                     5.0
# box1_wet_weight                                                                2.805
# box1_wet_weight_confirmation                                                   2.805
# box2_wet_weight                                                                3.405
# box2_wet_weight_confirmation                                                   3.405
# username_wet                                                                  nig047
# latitude_wet                                                               12.061702
# longitude_wet                                                               9.167225
# altitude_wet                                                                  453.98
# accuracy_wet                                                                     5.0
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                  2.8
# box1_dry_weight_confirmation                                                     2.8
# box2_dry_weight                                                                3.395
# box2_dry_weight_confirmation                                                   3.395
# latitude                                                                   12.059853
# longitude                                                                   9.167331
# altitude                                                                      441.35
# accuracy                                                                         5.0
#
#                                                                                 1637  \
# client_name                                                                        A
# distance_to_water_body                                                More_than_5_KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                          Niger
# field_irrigated                                                                   no
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        8a8c9f1a-8f2e-4afa-87a4-8872c67d37e3
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                                NaN
# username_box                                                                  nig103
# latitude_box                                                                9.927819
# longitude_box                                                               4.554482
# altitude_box                                                                   148.5
# accuracy_box                                                                     6.0
# box1_wet_weight                                                                1.625
# box1_wet_weight_confirmation                                                   1.625
# box2_wet_weight                                                                2.475
# box2_wet_weight_confirmation                                                   2.475
# username_wet                                                                  nig103
# latitude_wet                                                                9.912247
# longitude_wet                                                               4.413781
# altitude_wet                                                                   232.8
# accuracy_wet                                                                    2.96
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                1.545
# box1_dry_weight_confirmation                                                   1.545
# box2_dry_weight                                                                 2.42
# box2_dry_weight_confirmation                                                    2.42
# latitude                                                                    9.912232
# longitude                                                                   4.413828
# altitude                                                                       238.3
# accuracy                                                                         3.9
#
#                                                                                 964   \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                           Kano
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        cf2f299a-7fe1-499e-8209-06ebf71a5e8f
# type_of_irrigation_system                                                  tube_well
# other_crops_names                                                                NaN
# username_box                                                                  nig045
# latitude_box                                                               11.486372
# longitude_box                                                               9.260932
# altitude_box                                                                  449.77
# accuracy_box                                                                     4.6
# box1_wet_weight                                                                13.63
# box1_wet_weight_confirmation                                                   13.63
# box2_wet_weight                                                                13.51
# box2_wet_weight_confirmation                                                   13.51
# username_wet                                                                  nig045
# latitude_wet                                                               11.543892
# longitude_wet                                                               9.258429
# altitude_wet                                                                  475.39
# accuracy_wet                                                                    6.78
# ...
# farmer_in_list_or_control                                             control_farmer
# farmer_state_district                                                          Niger
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                           rows
# box2_mode_of_planting                                                           rows
# @case_id                                        7ad9f9fe-27a3-406b-bf73-6195f225cf1f
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                                NaN
# username_box                                                                  nig101
# latitude_box                                                                8.929684
# longitude_box                                                               5.789287
# altitude_box                                                                    90.4
# accuracy_box                                                                    5.88
# box1_wet_weight                                                                  4.4
# box1_wet_weight_confirmation                                                     4.4
# box2_wet_weight                                                                  4.2
# box2_wet_weight_confirmation                                                     4.2
# username_wet                                                                  nig101
# latitude_wet                                                                8.949401
# longitude_wet                                                               5.796556
# altitude_wet                                                                   100.3
# accuracy_wet                                                                     9.0
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                  4.4
# box1_dry_weight_confirmation                                                     4.4
# box2_dry_weight                                                                 4.15
# box2_dry_weight_confirmation                                                    4.15
# latitude                                                                    8.949419
# longitude                                                                   5.796665
# altitude                                                                        99.9
# accuracy                                                                        4.98
#
#                                                                                 24    \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                             control_farmer
# farmer_state_district                                                        Katsina
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        b9b67efb-85c8-4426-983a-4c21a8a62797
# type_of_irrigation_system                                                     rivers
# other_crops_names                                                                NaN
# username_box                                                                  nig190
# latitude_box                                                               11.882628
# longitude_box                                                               7.643849
# altitude_box                                                                   598.0
# accuracy_box                                                                    4.69
# box1_wet_weight                                                                  NaN
# box1_wet_weight_confirmation                                                     NaN
# box2_wet_weight                                                                  NaN
# box2_wet_weight_confirmation                                                     NaN
# username_wet                                                                     NaN
# latitude_wet                                                                     NaN
# longitude_wet                                                                    NaN
# altitude_wet                                                                     NaN
# accuracy_wet                                                                     NaN
# did_the_farmer_keep_the_crops_in_separate_bags                                   NaN
# farmer_verified_y                                                                NaN
# box1_dry_weight                                                                  NaN
# box1_dry_weight_confirmation                                                     NaN
# box2_dry_weight                                                                  NaN
# box2_dry_weight_confirmation                                                     NaN
# latitude                                                                         NaN
# longitude                                                                        NaN
# altitude                                                                         NaN
# accuracy                                                                         NaN
#
#                                                                                 2125  \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                         Bauchi
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        cbc124d2-c060-4877-8441-861db21a1370
# type_of_irrigation_system                                                   borehole
# other_crops_names                                                                NaN
# username_box                                                                  nig024
# latitude_box                                                               11.191243
# longitude_box                                                               9.731922
# altitude_box                                                                   430.0
# accuracy_box                                                                    4.03
# box1_wet_weight                                                                  3.6
# box1_wet_weight_confirmation                                                     3.6
# box2_wet_weight                                                                3.745
# box2_wet_weight_confirmation                                                   3.745
# username_wet                                                                  nig024
# latitude_wet                                                               11.207398
# longitude_wet                                                               9.752107
# altitude_wet                                                                   423.9
# accuracy_wet                                                                    3.78
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 3.52
# box1_dry_weight_confirmation                                                    3.52
# box2_dry_weight                                                                3.445
# box2_dry_weight_confirmation                                                   3.445
# latitude                                                                   11.207473
# longitude                                                                   9.752177
# altitude                                                                       420.7
# accuracy                                                                        2.54
#
#                                                                                 1241  \
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                             control_farmer
# farmer_state_district                                                          Niger
# field_irrigated                                                                  yes
# insured_crop                                                                   wheat
# intercropping                                                                     no
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        9a6cffe0-52d0-4899-a098-ebec6923db45
# type_of_irrigation_system                                                   borehole
# other_crops_names                                                                NaN
# username_box                                                                  nig097
# latitude_box                                                                 8.92374
# longitude_box                                                               5.791074
# altitude_box                                                                   94.87
# accuracy_box                                                                    4.93
# box1_wet_weight                                                                 1.58
# box1_wet_weight_confirmation                                                    1.58
# box2_wet_weight                                                                1.525
# box2_wet_weight_confirmation                                                   1.525
# username_wet                                                                  nig097
# latitude_wet                                                                8.950953
# longitude_wet                                                               5.794932
# altitude_wet                                                                  132.34
# accuracy_wet                                                                    4.91
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 1.57
# box1_dry_weight_confirmation                                                    1.57
# box2_dry_weight                                                                1.535
# box2_dry_weight_confirmation                                                   1.535
# latitude                                                                    8.951026
# longitude                                                                   5.794542
# altitude                                                                       126.9
# accuracy                                                                        4.96
#
#                                                                                 2029
# client_name                                                                        A
# distance_to_water_body                                                         0-5KM
# farmer_in_list_or_control                                              farmer_listed
# farmer_state_district                                                         Bauchi
# field_irrigated                                                                   no
# insured_crop                                                                   wheat
# intercropping                                                                    yes
# box1_mode_of_planting                                                    broadcasted
# box2_mode_of_planting                                                    broadcasted
# @case_id                                        4517757f-c417-4d45-8eb2-cde4ce383d78
# type_of_irrigation_system                                                        NaN
# other_crops_names                                                              maize
# username_box                                                                  nig036
# latitude_box                                                               10.944988
# longitude_box                                                               9.596363
# altitude_box                                                                   474.1
# accuracy_box                                                                    3.49
# box1_wet_weight                                                                 6.81
# box1_wet_weight_confirmation                                                    6.81
# box2_wet_weight                                                                7.255
# box2_wet_weight_confirmation                                                   7.255
# username_wet                                                                  nig036
# latitude_wet                                                               10.946143
# longitude_wet                                                               9.598888
# altitude_wet                                                                   499.0
# accuracy_wet                                                                    4.75
# did_the_farmer_keep_the_crops_in_separate_bags                                   yes
# farmer_verified_y                                                    farmer_verified
# box1_dry_weight                                                                 6.43
# box1_dry_weight_confirmation                                                    6.43
# box2_dry_weight                                                                 6.96
# box2_dry_weight_confirmation                                                    6.96
# latitude                                                                   10.934041
# longitude                                                                   9.600269
# altitude                                                                       497.0
# accuracy                                                                         5.0

# %% [markdown]
# #### Assessment issues:
#
# > **Quality issues**
#
# > > * Q-2: Some values for latitude and longitude are not consistent for the 3 datasets
#
# > **Tidiness issues**
# > > T-1: originally common columns contin data in 3 different columns instead of one.
# > > T-3: There needs to be a column for confirmed box lengths

# %%
#Use code to count the crops
raw_focused_data.insured_crop.value_counts()
# Out:
# wheat    2356
# Name: insured_crop, dtype: int64

# %% [markdown]
# ### Programmatic assessment

# %%
#View information about the dataframe
raw_focused_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 36 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   client_name                                     2356 non-null   object
#  1   distance_to_water_body                          2297 non-null   object
#  2   farmer_in_list_or_control                       2356 non-null   object
#  3   farmer_state_district                           2356 non-null   object
#  4   field_irrigated                                 2297 non-null   object
#  5   insured_crop                                    2356 non-null   object
#  6   intercropping                                   2356 non-null   object
#  7   box1_mode_of_planting                           2244 non-null   object
#  8   box2_mode_of_planting                           2242 non-null   object
#  9   @case_id                                        2356 non-null   object
#  10  type_of_irrigation_system                       1528 non-null   object
#  11  other_crops_names                               230 non-null    object
#  12  username_box                                    2356 non-null   object
#  13  latitude_box                                    2356 non-null   float64
#  14  longitude_box                                   2356 non-null   float64
#  15  altitude_box                                    2356 non-null   float64
#  16  accuracy_box                                    2356 non-null   float64
#  17  box1_wet_weight                                 2131 non-null   float64
#  18  box1_wet_weight_confirmation                    2131 non-null   float64
#  19  box2_wet_weight                                 2129 non-null   float64
#  20  box2_wet_weight_confirmation                    2129 non-null   float64
#  21  username_wet                                    2234 non-null   object
#  22  latitude_wet                                    2134 non-null   float64
#  23  longitude_wet                                   2134 non-null   float64
#  24  altitude_wet                                    2134 non-null   float64
#  25  accuracy_wet                                    2134 non-null   float64
#  26  did_the_farmer_keep_the_crops_in_separate_bags  2102 non-null   object
#  27  farmer_verified_y                               2222 non-null   object
#  28  box1_dry_weight                                 2096 non-null   float64
#  29  box1_dry_weight_confirmation                    2096 non-null   float64
#  30  box2_dry_weight                                 2093 non-null   float64
#  31  box2_dry_weight_confirmation                    2093 non-null   float64
#  32  latitude                                        2102 non-null   float64
#  33  longitude                                       2102 non-null   float64
#  34  altitude                                        2102 non-null   float64
#  35  accuracy                                        2102 non-null   float64
# dtypes: float64(20), object(16)
# memory usage: 681.0+ KB

# %%
#We use code to find where the dry weights are greater than wet weights
box_1_invalid_dry_weights = raw_focused_data.query('box1_dry_weight > box1_wet_weight')[['username_box','box1_dry_weight','box1_wet_weight','box1_dry_weight_confirmation','box1_wet_weight_confirmation']]
box_1_invalid_dry_weights
# Out:
#      username_box  box1_dry_weight  box1_wet_weight  \
# 40         nig039            2.225            1.230
# 62         nig188            0.370            0.190
# 157        nig108            5.325            5.260
# 231        nig187            3.900            3.750
# 289        nig187            6.570            4.945
# ...           ...              ...              ...
# 2186       nig031            7.470            7.090
# 2232       nig026            5.270            5.075
# 2284       nig031            5.825            4.265
# 2287       nig031            7.190            3.265
# 2312       nig030            6.965            5.225
#
#       box1_dry_weight_confirmation  box1_wet_weight_confirmation
# 40                           2.225                         1.230
# 62                           0.370                         0.190
# 157                          5.325                         5.260
# 231                          3.900                         3.750
# 289                          6.570                         4.945
# ...                            ...                           ...
# 2186                         7.470                         7.090
# 2232                         5.270                         5.075
# 2284                         5.825                         4.265
# 2287                         7.190                         3.265
# 2312                         6.965                         5.225
#
# [77 rows x 5 columns]

# %%
#We use code to view rankings of enumerators who submit invalid data, by the dry weights greater than wet weights
box_1_invalid_dry_weights['username_box'].value_counts()[:12]
# Out:
# nig099    12
# nig106     7
# nig098     7
# nig090     5
# nig097     5
# nig031     3
# nig187     3
# nig026     3
# nig168     3
# nig033     2
# nig030     2
# nig028     2
# Name: username_box, dtype: int64

# %%
#We use code to find where the dry weights are greater than wet weights
box_2_invalid_dry_weights = raw_focused_data.query('box2_dry_weight > box2_wet_weight')[['username_box','box2_dry_weight','box2_wet_weight','box2_dry_weight_confirmation','box2_wet_weight_confirmation']]
box_2_invalid_dry_weights
# Out:
#      username_box  box2_dry_weight  box2_wet_weight  \
# 56         nig099            4.470            3.520
# 138        nig168            9.630            8.870
# 150        nig108            1.500            1.425
# 154        nig108            5.310            5.275
# 155        nig108            5.335            5.225
# ...           ...              ...              ...
# 2283       nig031            7.265            5.345
# 2285       nig031            7.245            3.520
# 2305       nig031            6.875            4.800
# 2312       nig030            4.605            2.665
# 2343       nig033            2.335            2.025
#
#       box2_dry_weight_confirmation  box2_wet_weight_confirmation
# 56                           4.470                         3.520
# 138                          9.630                         8.870
# 150                          1.500                         1.425
# 154                          5.310                         5.275
# 155                          5.335                         5.225
# ...                            ...                           ...
# 2283                         7.265                         5.345
# 2285                         7.245                         3.520
# 2305                         6.875                         4.800
# 2312                         4.605                         2.665
# 2343                         2.335                         2.025
#
# [94 rows x 5 columns]

# %%
#We use code to view rankings of enumerators who submit invalid data, by the dry weights greater than wet weights
box_2_invalid_dry_weights['username_box'].value_counts()[:12]
# Out:
# nig099    12
# nig106     9
# nig031     5
# nig097     5
# nig098     5
# nig090     5
# nig183     3
# nig102     3
# nig108     3
# nig030     3
# nig033     3
# nig168     3
# Name: username_box, dtype: int64

# %%
# We use code to view data where we have wet weight value, but missing dry weights value for box 1
raw_focused_data.query('box1_wet_weight.notnull() & box1_dry_weight.isna()')[['box1_wet_weight','box1_dry_weight']]
# Out:
#       box1_wet_weight  box1_dry_weight
# 0               8.580              NaN
# 66              3.590              NaN
# 67              2.665              NaN
# 68              3.300              NaN
# 88              2.395              NaN
# 89              3.525              NaN
# 91              3.385              NaN
# 92              2.620              NaN
# 97              7.035              NaN
# 350             5.350              NaN
# 733             8.580              NaN
# 734            10.730              NaN
# 735             8.305              NaN
# 737            10.790              NaN
# 738             9.225              NaN
# 739            10.660              NaN
# 740            14.660              NaN
# 741             9.750              NaN
# 1152            3.400              NaN
# 1245           14.190              NaN
# 1388            1.525              NaN
# 1428            3.210              NaN
# 1482            4.955              NaN
# 1484            3.910              NaN
# 1488            2.645              NaN
# 1576            4.075              NaN
# 1577            4.410              NaN
# 1601            1.350              NaN
# 1788            7.045              NaN
# 1890            6.920              NaN
# 1895            6.695              NaN
# 2007            7.595              NaN
# 2254            5.700              NaN
# 2301            4.050              NaN
# 2313            3.870              NaN

# %%
# We use code to view data where we have wet weight value, but missing dry weights value for box 2
raw_focused_data.query('box2_wet_weight.notnull() & box2_dry_weight.isna()')[['box2_wet_weight','box2_dry_weight']]
# Out:
#       box2_wet_weight  box2_dry_weight
# 0               3.740              NaN
# 66              3.785              NaN
# 67              2.355              NaN
# 68              3.420              NaN
# 88              3.020              NaN
# 89              3.559              NaN
# 91              2.825              NaN
# 92              3.110              NaN
# 97              7.350              NaN
# 350             6.620              NaN
# 733             7.470              NaN
# 734            11.140              NaN
# 735             7.925              NaN
# 737             9.490              NaN
# 738             8.165              NaN
# 739            11.560              NaN
# 740            10.930              NaN
# 741            11.690              NaN
# 1152            3.240              NaN
# 1245           13.230              NaN
# 1372            1.575              NaN
# 1388            0.760              NaN
# 1428            3.190              NaN
# 1482            4.250              NaN
# 1484            2.560              NaN
# 1488            2.305              NaN
# 1576            2.420              NaN
# 1577            3.855              NaN
# 1601            1.070              NaN
# 1788            5.175              NaN
# 1890            8.165              NaN
# 1895            8.240              NaN
# 2007            5.145              NaN
# 2254            6.055              NaN
# 2301            3.185              NaN
# 2313            3.315              NaN

# %%
# We find the average proportion of dry weights to wet weights for wheat using proportion of means
((raw_focused_data.box1_dry_weight.mean()+raw_focused_data.box2_dry_weight.mean()))/(raw_focused_data.box1_wet_weight.mean()+raw_focused_data.box2_wet_weight.mean())
# Out:
# 0.8571994164633013

# %%
# We find missing values of wet weight that have a dry weight of 0 for box 1
raw_focused_data.query('box1_wet_weight.isna() & box1_dry_weight == "0"')[['box1_wet_weight','box1_dry_weight']]
# Out:
# Empty DataFrame
# Columns: [box1_wet_weight, box1_dry_weight]
# Index: []

# %%
# We find missing values of wet weight that have a dry weight of 0 for box 2
raw_focused_data.query('box2_wet_weight.isna() & box2_dry_weight.notna()')[['box2_wet_weight','box2_dry_weight']]
# Out:
# Empty DataFrame
# Columns: [box2_wet_weight, box2_dry_weight]
# Index: []

# %%
#We check to see whether dry weights match dry weights confirmation for all values
(raw_focused_data.box2_dry_weight == raw_focused_data.box2_dry_weight_confirmation).value_counts()
# Out:
# True     2093
# False     263
# dtype: int64

# %% [markdown]
# Q-x: There are falsely missing dry values, since wet produce does not dry to 0
# Q-x: The weights differ from the confirmed weights.

# %% [markdown]
# ## Assessment summary

# %% [markdown]
# > **Quality issues**
#
# > > * Q-1 Extra unnecesary columns, order of columns is not the best
# > > * Q-2: Some values for latitude and longitude are not consistent for the 3 datasets
# > > * Q-3: There is need for a yields column
# > > * Q-4: Box 1 dry weights has values which are greater than the corresponding wet weights
# > > * Q-5: Box 2 dry weights has values which are greater than the corresponding wet weights
# > > * Q-6: Box 1 dry weights has values which have wet weights but no dry weights hence wrongfully missing
# > > * Q-7: Box 2 dry weights has values which have wet weights but no dry weights hence wrongfully missing
# > > * Q-8: There is a mismatch of weights and their confirmed weights
#
# > **Tidiness issues**
# > > T-1: originally common columns contin data in 3 different columns instead of one.
# > > T-3: There needs to be a column for confirmed box lengths

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Issue Q-6 and Q-7:
#
# > > * Q-6: Box 1 dry weights has values which have wet weights but no dry weights hence wrongfully missing
# > > * Q-7: Box 2 dry weights has values which have wet weights but no dry weights hence wrongfully missing

# %% [markdown]
# ### Define:
#
# For both values we use the calculated estimate proportion to fill the missing values

# %% [markdown]
# ### Code

# %%
#calculate and fill missing values for wrongly missing box1 dry weights
for i in raw_focused_data.query('box1_wet_weight.notnull() & box1_dry_weight.isna()')[['box1_wet_weight','box1_dry_weight']].index:
    raw_focused_data.loc[i,'box1_dry_weight'] = raw_focused_data.loc[i,'box1_wet_weight']*0.8571994164633013

# %%
#calculate and fill missing values for wrongly missing box1 dry weights
for i in raw_focused_data.query('box2_wet_weight.notnull() & box2_dry_weight.isna()')[['box2_wet_weight','box2_dry_weight']].index:
    raw_focused_data.loc[i,'box2_dry_weight'] = raw_focused_data.loc[i,'box2_wet_weight']*0.8571994164633013

# %% [markdown]
# ## Test

# %%
# We confirm if the dry weights have been filled for box 2
raw_focused_data.query('box2_wet_weight.notnull() & box2_dry_weight.isna()')[['box2_wet_weight','box2_dry_weight']]
# Out:
# Empty DataFrame
# Columns: [box2_wet_weight, box2_dry_weight]
# Index: []

# %%
# We confirm if the dry weights have been filled for box 1
raw_focused_data.query('box1_wet_weight.notnull() & box1_dry_weight.isna()')[['box1_wet_weight','box1_dry_weight']]
# Out:
# Empty DataFrame
# Columns: [box1_wet_weight, box1_dry_weight]
# Index: []

# %% [markdown]
# Both missing values have been filled.

# %% [markdown]
# ### Issue Q-8 and Q-9:
#
# > > * Q-8: There is a mismatch of weights and their confirmed weights
# > > * Q-9: There is need for a yields column

# %% [markdown]
# ### Define:
#
# > > * Due to the difference in confirmed weights and weights, we assume confirmed weights are correct and use them to fill yields column

# %% [markdown]
# ### Code:

# %%
#Find entries where box 1 dry weights are not equal to their confirmation and either the 
#box1 dry weight or the confirmation has an entry
raw_focused_data.query('(box1_dry_weight_confirmation != box1_dry_weight) & (box1_dry_weight_confirmation.notna()| box1_dry_weight.notna())')[['box1_dry_weight','box1_dry_weight_confirmation']]
# Out:
#       box1_dry_weight  box1_dry_weight_confirmation
# 0            7.354771                           NaN
# 66           3.077346                           NaN
# 67           2.284436                           NaN
# 68           2.828758                           NaN
# 88           2.052993                           NaN
# 89           3.021628                           NaN
# 91           2.901620                           NaN
# 92           2.245862                           NaN
# 97           6.030398                           NaN
# 350          4.586017                           NaN
# 733          7.354771                           NaN
# 734          9.197750                           NaN
# 735          7.119041                           NaN
# 737          9.249182                           NaN
# 738          7.907665                           NaN
# 739          9.137746                           NaN
# 740         12.566543                           NaN
# 741          8.357694                           NaN
# 1152         2.914478                           NaN
# 1245        12.163660                           NaN
# 1388         1.307229                           NaN
# 1428         2.751610                           NaN
# 1482         4.247423                           NaN
# 1484         3.351650                           NaN
# 1488         2.267292                           NaN
# 1576         3.493088                           NaN
# 1577         3.780249                           NaN
# 1601         1.157219                           NaN
# 1788         6.038970                           NaN
# 1890         5.931820                           NaN
# 1895         5.738950                           NaN
# 2007         6.510430                           NaN
# 2254         4.886037                           NaN
# 2301         3.471658                           NaN
# 2313         3.317362                           NaN

# %% [markdown]
# > Confirmed the difference is due to skipped confirmation and is nor erroneous.

# %%
#We compute yields
raw_focused_data['yield_kgs'] = (raw_focused_data.box1_dry_weight+raw_focused_data.box2_dry_weight)

# %% [markdown]
# ### Test

# %%
#Test if successful in computation of yields
raw_focused_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   client_name                                     2356 non-null   object
#  1   distance_to_water_body                          2297 non-null   object
#  2   farmer_in_list_or_control                       2356 non-null   object
#  3   farmer_state_district                           2356 non-null   object
#  4   field_irrigated                                 2297 non-null   object
#  5   insured_crop                                    2356 non-null   object
#  6   intercropping                                   2356 non-null   object
#  7   box1_mode_of_planting                           2244 non-null   object
#  8   box2_mode_of_planting                           2242 non-null   object
#  9   @case_id                                        2356 non-null   object
#  10  type_of_irrigation_system                       1528 non-null   object
#  11  other_crops_names                               230 non-null    object
#  12  username_box                                    2356 non-null   object
#  13  latitude_box                                    2356 non-null   float64
#  14  longitude_box                                   2356 non-null   float64
#  15  altitude_box                                    2356 non-null   float64
#  16  accuracy_box                                    2356 non-null   float64
#  17  box1_wet_weight                                 2131 non-null   float64
#  18  box1_wet_weight_confirmation                    2131 non-null   float64
#  19  box2_wet_weight                                 2129 non-null   float64
#  20  box2_wet_weight_confirmation                    2129 non-null   float64
#  21  username_wet                                    2234 non-null   object
#  22  latitude_wet                                    2134 non-null   float64
#  23  longitude_wet                                   2134 non-null   float64
#  24  altitude_wet                                    2134 non-null   float64
#  25  accuracy_wet                                    2134 non-null   float64
#  26  did_the_farmer_keep_the_crops_in_separate_bags  2102 non-null   object
#  27  farmer_verified_y                               2222 non-null   object
#  28  box1_dry_weight                                 2131 non-null   float64
#  29  box1_dry_weight_confirmation                    2096 non-null   float64
#  30  box2_dry_weight                                 2129 non-null   float64
#  31  box2_dry_weight_confirmation                    2093 non-null   float64
#  32  latitude                                        2102 non-null   float64
#  33  longitude                                       2102 non-null   float64
#  34  altitude                                        2102 non-null   float64
#  35  accuracy                                        2102 non-null   float64
#  36  yield_kgs                                       2126 non-null   float64
# dtypes: float64(21), object(16)
# memory usage: 764.0+ KB

# %% [markdown]
# ### Issue Q-4 and Q-5:
#
# > > * Q-4: Box 1 dry weights has values which are greater than the corresponding wet weights
# > > * Q-5: Box 2 dry weights has values which are greater than the corresponding wet weights

# %% [markdown]
# ### Define:
#
# The values of dry weights greater than wet weights are incorrect and should be replaced by 85% wet weight

# %% [markdown]
# ### Code

# %%
#calculate and fill missing values for wrongly missing box1 dry weights
for i in raw_focused_data.query('box1_dry_weight > box1_wet_weight')[['username_box','box1_dry_weight','box1_wet_weight','box1_dry_weight_confirmation','box1_wet_weight_confirmation']].index:
    raw_focused_data.loc[i,'box1_dry_weight'] = raw_focused_data.loc[i,'box1_wet_weight']*0.8571994164633013

# %%
#calculate and fill missing values for wrongly missing box1 dry weights
for i in raw_focused_data.query('box2_dry_weight > box2_wet_weight')[['username_box','box2_dry_weight','box2_wet_weight','box2_dry_weight_confirmation','box2_wet_weight_confirmation']].index:
    raw_focused_data.loc[i,'box2_dry_weight'] = raw_focused_data.loc[i,'box2_wet_weight']*0.8571994164633013

# %% [markdown]
# ### Test

# %%
# Confirm if the missing box1 dry weights have been filled
raw_focused_data.query('box1_dry_weight > box1_wet_weight')[['username_box','box1_dry_weight','box1_wet_weight','box1_dry_weight_confirmation','box1_wet_weight_confirmation']]
# Out:
# Empty DataFrame
# Columns: [username_box, box1_dry_weight, box1_wet_weight, box1_dry_weight_confirmation, box1_wet_weight_confirmation]
# Index: []

# %%
#confirm if the missing box 2 dry weights have been filled
raw_focused_data.query('box2_dry_weight > box2_wet_weight')[['username_box','box2_dry_weight','box2_wet_weight','box2_dry_weight_confirmation','box2_wet_weight_confirmation']]
# Out:
# Empty DataFrame
# Columns: [username_box, box2_dry_weight, box2_wet_weight, box2_dry_weight_confirmation, box2_wet_weight_confirmation]
# Index: []

# %% [markdown]
# > * The incorrect values are fixed

# %%
# View first rows
raw_focused_data.head()
# Out:
#   client_name distance_to_water_body farmer_in_list_or_control  \
# 0           A                  0-5KM             farmer_listed
# 1           A         More_than_5_KM            control_farmer
# 2           A         More_than_5_KM            control_farmer
# 3           A         More_than_5_KM            control_farmer
# 4           A         More_than_5_KM            control_farmer
#
#   farmer_state_district field_irrigated insured_crop intercropping  \
# 0               Katsina              no        wheat            no
# 1               Katsina              no        wheat            no
# 2               Zamfara              no        wheat            no
# 3               Zamfara              no        wheat            no
# 4               Zamfara              no        wheat            no
#
#   box1_mode_of_planting box2_mode_of_planting  \
# 0           broadcasted           broadcasted
# 1           broadcasted           broadcasted
# 2           broadcasted           broadcasted
# 3           broadcasted           broadcasted
# 4           broadcasted           broadcasted
#
#                                @case_id  ... farmer_verified_y  \
# 0  b8a79a54-442e-4d79-9656-65af4e6c5733  ...               NaN
# 1  36311aa7-29d1-4650-a230-830bcd565d72  ...   farmer_verified
# 2  0a9e2724-59e1-48cd-ab48-856dce787fec  ...   farmer_verified
# 3  da9f7363-2415-415e-8cef-d6bb18ed2bc0  ...   farmer_verified
# 4  9a14fb60-c3a6-4794-9f92-e84953db4b32  ...   farmer_verified
#
#   box1_dry_weight box1_dry_weight_confirmation  box2_dry_weight  \
# 0        7.354771                          NaN         3.205926
# 1        5.630000                        5.630         3.760000
# 2        2.690000                        2.690         2.720000
# 3        2.185000                        2.185         2.520000
# 4        3.155000                        3.155         3.135000
#
#    box2_dry_weight_confirmation   latitude  longitude  altitude  accuracy  \
# 0                           NaN        NaN        NaN       NaN       NaN
# 1                         3.760  11.368059   7.568079    721.23      8.00
# 2                         2.720  12.147570   6.714653    107.00      1.49
# 3                         2.520  12.138754   6.686328    107.00      1.47
# 4                         3.135  12.138754   6.686328    107.00      1.48
#
#    yield_kgs
# 0  10.560697
# 1   9.390000
# 2   5.410000
# 3   4.705000
# 4   6.290000
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Issue Q-2:
#
# > > * Q-2: Some values for latitude and longitude are not consistent for the 3 datasets

# %% [markdown]
# ### Define:
#
# > Q-2 we try to come up with one longitude and 1 latitude column

# %% [markdown]
# ### Code

# %%
# fird entryies where the longitudes data differ
raw_focused_data.query('(longitude != longitude_box) != longitude_wet')[['longitude','longitude_box','longitude']]
# Out:
#       longitude  longitude_box  longitude
# 0           NaN       7.568032        NaN
# 1      7.568079       7.567983   7.568079
# 2      6.714653       6.640337   6.714653
# 3      6.686328       6.640337   6.686328
# 4      6.686328       6.640011   6.686328
# ...         ...            ...        ...
# 2351   9.767911      10.038590   9.767911
# 2352   9.767942      10.038638   9.767942
# 2353   9.767955      10.038635   9.767955
# 2354   9.767941      10.038600   9.767941
# 2355   9.767950      10.038725   9.767950
#
# [2356 rows x 3 columns]

# %%
#Count missing values in longitude column
raw_focused_data.longitude.isna().sum()
# Out:
# 254

# %%
#Count missing values in longitude_box column
raw_focused_data.longitude_box.isna().sum()
# Out:
# 0

# %%
#Count missing values in longitude_wet column
raw_focused_data.longitude_wet.isna().sum()
# Out:
# 222

# %%
# create new longitude column
raw_focused_data['new_longitude'] = raw_focused_data.longitude_box

# %%
# Find entries where latitude values differ
raw_focused_data.query('(latitude != latitude_box) != latitude_wet')[['latitude','latitude_box','latitude_wet']]
# Out:
#        latitude  latitude_box  latitude_wet
# 0           NaN     11.367974     11.367886
# 1     11.368059     11.367970     11.368021
# 2     12.147570     12.046592     12.147570
# 3     12.138754     12.046592     12.138754
# 4     12.138754     12.051899     12.138754
# ...         ...           ...           ...
# 2351  10.698531     10.345576     10.431895
# 2352  10.698552     10.345682     10.431937
# 2353  10.698556     10.345614     10.431910
# 2354  10.698525     10.345495     10.431854
# 2355  10.698528     10.345544     10.431863
#
# [2356 rows x 3 columns]

# %%
# Count missing values in latitude column
raw_focused_data.latitude.isna().sum()
# Out:
# 254

# %%
# Count missing values in latitude_box column
raw_focused_data.latitude_box.isna().sum()
# Out:
# 0

# %%
# Count missing values in latitude_wet column
raw_focused_data.latitude_wet.isna().sum()
# Out:
# 222

# %%
#create new latitude column
raw_focused_data['new_latitude'] = raw_focused_data.latitude_box

# %% [markdown]
# ### Test

# %%
#Confirm column creation
raw_focused_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 39 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   client_name                                     2356 non-null   object
#  1   distance_to_water_body                          2297 non-null   object
#  2   farmer_in_list_or_control                       2356 non-null   object
#  3   farmer_state_district                           2356 non-null   object
#  4   field_irrigated                                 2297 non-null   object
#  5   insured_crop                                    2356 non-null   object
#  6   intercropping                                   2356 non-null   object
#  7   box1_mode_of_planting                           2244 non-null   object
#  8   box2_mode_of_planting                           2242 non-null   object
#  9   @case_id                                        2356 non-null   object
#  10  type_of_irrigation_system                       1528 non-null   object
#  11  other_crops_names                               230 non-null    object
#  12  username_box                                    2356 non-null   object
#  13  latitude_box                                    2356 non-null   float64
#  14  longitude_box                                   2356 non-null   float64
#  15  altitude_box                                    2356 non-null   float64
#  16  accuracy_box                                    2356 non-null   float64
#  17  box1_wet_weight                                 2131 non-null   float64
#  18  box1_wet_weight_confirmation                    2131 non-null   float64
#  19  box2_wet_weight                                 2129 non-null   float64
#  20  box2_wet_weight_confirmation                    2129 non-null   float64
#  21  username_wet                                    2234 non-null   object
#  22  latitude_wet                                    2134 non-null   float64
#  23  longitude_wet                                   2134 non-null   float64
#  24  altitude_wet                                    2134 non-null   float64
#  25  accuracy_wet                                    2134 non-null   float64
#  26  did_the_farmer_keep_the_crops_in_separate_bags  2102 non-null   object
#  27  farmer_verified_y                               2222 non-null   object
#  28  box1_dry_weight                                 2131 non-null   float64
#  29  box1_dry_weight_confirmation                    2096 non-null   float64
#  30  box2_dry_weight                                 2129 non-null   float64
#  31  box2_dry_weight_confirmation                    2093 non-null   float64
#  32  latitude                                        2102 non-null   float64
#  33  longitude                                       2102 non-null   float64
#  34  altitude                                        2102 non-null   float64
#  35  accuracy                                        2102 non-null   float64
#  36  yield_kgs                                       2126 non-null   float64
#  37  new_longitude                                   2356 non-null   float64
#  38  new_latitude                                    2356 non-null   float64
# dtypes: float64(23), object(16)
# memory usage: 800.8+ KB

# %% [markdown]
# ## Issue Q-1:
#
# > > * Q-1 Extra unnecesary columns, order of columns is not the best

# %% [markdown]
# ## Define:
#
# > * We we choose the final most relevant columns and reorder them for bset analysis

# %% [markdown]
# ## Code

# %%
#View columns
raw_focused_data.columns
# Out:
# Index(['client_name', 'distance_to_water_body', 'farmer_in_list_or_control',
#        'farmer_state_district', 'field_irrigated', 'insured_crop',
#        'intercropping', 'box1_mode_of_planting', 'box2_mode_of_planting',
#        '@case_id', 'type_of_irrigation_system', 'other_crops_names',
#        'username_box', 'latitude_box', 'longitude_box', 'altitude_box',
#        'accuracy_box', 'box1_wet_weight', 'box1_wet_weight_confirmation',
#        'box2_wet_weight', 'box2_wet_weight_confirmation', 'username_wet',
#        'latitude_wet', 'longitude_wet', 'altitude_wet', 'accuracy_wet',
#        'did_the_farmer_keep_the_crops_in_separate_bags', 'farmer_verified_y',
#        'box1_dry_weight', 'box1_dry_weight_confirmation', 'box2_dry_weight',
#        'box2_dry_weight_confirmation', 'latitude', 'longitude', 'altitude',
#        'accuracy', 'yield_kgs', 'new_longitude', 'new_latitude'],
#       dtype='object')

# %%
#Select needed columns and rearrange for best display
cleaned_focused_data = raw_focused_data[[
       #basic details
       '@case_id','client_name', 'distance_to_water_body', 'insured_crop',
       'farmer_state_district',
       #Farmer status
       'farmer_in_list_or_control', 'farmer_verified_y',
       #Farming options
       'field_irrigated', 'intercropping',
       'did_the_farmer_keep_the_crops_in_separate_bags',
       'box1_mode_of_planting', 'box2_mode_of_planting',
       'type_of_irrigation_system', 'other_crops_names',
         #Enumerators                                
       'username_box',
        #Weights
        'yield_kgs',
        #Spartial data                               
       'new_latitude', 'new_longitude' , 'altitude_box', 'accuracy_box']]

# %%
#Rename columns
cleaned_focused_data.columns = [
       #basic details
       'case_id','client_name', 'distance_to_water_body', 'insured_crop',
       'farmer_state_district',
       #Farmer status
       'farmer_in_list_or_control', 'farmer_verified',
       #Farming options
       'field_irrigated', 'intercropping',
       'crops_kept_in_separate_bags',
       'box1_mode_of_planting', 'box2_mode_of_planting',
       'type_of_irrigation_system', 'other_crops_names',
         #Enumerators                                
       'name_of_enumerator',
        #Weights
        'yield_kgs',
        #Spartial data                               
       'new_latitude', 'new_longitude' , 'new_altitude', 'new_accuracy']

# %% [markdown]
# ## Test

# %%
#confirm column order and renaming
cleaned_focused_data.columns
# Out:
# Index(['case_id', 'client_name', 'distance_to_water_body', 'insured_crop',
#        'farmer_state_district', 'farmer_in_list_or_control', 'farmer_verified',
#        'field_irrigated', 'intercropping', 'crops_kept_in_separate_bags',
#        'box1_mode_of_planting', 'box2_mode_of_planting',
#        'type_of_irrigation_system', 'other_crops_names', 'name_of_enumerator',
#        'yield_kgs', 'new_latitude', 'new_longitude', 'new_altitude',
#        'new_accuracy'],
#       dtype='object')

# %%
#View the data
cleaned_focused_data.head()
# Out:
#                                 case_id client_name distance_to_water_body  \
# 0  b8a79a54-442e-4d79-9656-65af4e6c5733           A                  0-5KM
# 1  36311aa7-29d1-4650-a230-830bcd565d72           A         More_than_5_KM
# 2  0a9e2724-59e1-48cd-ab48-856dce787fec           A         More_than_5_KM
# 3  da9f7363-2415-415e-8cef-d6bb18ed2bc0           A         More_than_5_KM
# 4  9a14fb60-c3a6-4794-9f92-e84953db4b32           A         More_than_5_KM
#
#   insured_crop farmer_state_district farmer_in_list_or_control  \
# 0        wheat               Katsina             farmer_listed
# 1        wheat               Katsina            control_farmer
# 2        wheat               Zamfara            control_farmer
# 3        wheat               Zamfara            control_farmer
# 4        wheat               Zamfara            control_farmer
#
#    farmer_verified field_irrigated intercropping crops_kept_in_separate_bags  \
# 0              NaN              no            no                         NaN
# 1  farmer_verified              no            no                         yes
# 2  farmer_verified              no            no                         yes
# 3  farmer_verified              no            no                         yes
# 4  farmer_verified              no            no                         yes
#
#   box1_mode_of_planting box2_mode_of_planting type_of_irrigation_system  \
# 0           broadcasted           broadcasted                       NaN
# 1           broadcasted           broadcasted                       NaN
# 2           broadcasted           broadcasted                       NaN
# 3           broadcasted           broadcasted                       NaN
# 4           broadcasted           broadcasted                       NaN
#
#   other_crops_names name_of_enumerator  yield_kgs  new_latitude  \
# 0               NaN             nig187  10.560697     11.367974
# 1               NaN             nig187   9.390000     11.367970
# 2               NaN             nig040   5.410000     12.046592
# 3               NaN             nig040   4.705000     12.046592
# 4               NaN             nig040   6.290000     12.051899
#
#    new_longitude  new_altitude  new_accuracy
# 0       7.568032        717.83          6.16
# 1       7.567983        696.77          4.25
# 2       6.640337         65.00          1.00
# 3       6.640337         65.00          3.90
# 4       6.640011         65.00          1.00

# %%
#Chech the data shape
cleaned_focused_data.shape
# Out:
# (2356, 20)

# %%
#View samples from the data 
cleaned_focused_data.sample(8)
# Out:
#                                    case_id client_name distance_to_water_body  \
# 187   8a84ddef-174e-4f7c-8888-69b0484d0c23           A         More_than_5_KM
# 1700  faa6e050-96a8-450c-9251-f2a617867d9c           A                  0-5KM
# 2213  b9455412-6790-4215-b831-d3805c570312           A                  0-5KM
# 1771  4ac98e26-2057-4556-81b4-e8e3895b5ecd           A                  0-5KM
# 1192  b42903e7-7756-4fcf-8b3f-6451d0aef19c           A                  0-5KM
# 2221  80efe827-aa08-4142-babb-a787fc687cdc           A                  0-5KM
# 845   87180b70-2bb6-4d07-9ce2-7b78660efd47           A                  0-5KM
# 402   b4271e7c-6135-4878-8fd0-d271069c2f01           A                  0-5KM
#
#      insured_crop farmer_state_district farmer_in_list_or_control  \
# 187         wheat                 Borno             farmer_listed
# 1700        wheat                  Kano             farmer_listed
# 2213        wheat                Bauchi             farmer_listed
# 1771        wheat                Taraba             farmer_listed
# 1192        wheat                Bauchi             farmer_listed
# 2221        wheat                Bauchi             farmer_listed
# 845         wheat                 Niger            control_farmer
# 402         wheat                Bauchi             farmer_listed
#
#       farmer_verified field_irrigated intercropping  \
# 187   farmer_verified             yes            no
# 1700  farmer_verified             yes            no
# 2213  farmer_verified             yes            no
# 1771  farmer_verified             yes            no
# 1192  farmer_verified             yes            no
# 2221  farmer_verified              no            no
# 845   farmer_verified             yes            no
# 402   farmer_verified             yes            no
#
#      crops_kept_in_separate_bags box1_mode_of_planting box2_mode_of_planting  \
# 187                          yes           broadcasted           broadcasted
# 1700                         yes                  rows                  rows
# 2213                         yes           broadcasted           broadcasted
# 1771                         yes                  rows                  rows
# 1192                         yes           broadcasted           broadcasted
# 2221                         yes                  rows                  rows
# 845                          yes                  rows                  rows
# 402                          yes                  rows                  rows
#
#      type_of_irrigation_system other_crops_names name_of_enumerator  \
# 187                        Dam               NaN             nig174
# 1700                    rivers               NaN             nig045
# 2213                  borehole               NaN             nig024
# 1771                 tube_well               NaN             nig125
# 1192                 tube_well               NaN             nig026
# 2221                       NaN               NaN             nig031
# 845                  tube_well               NaN             nig120
# 402                        Dam               NaN             nig034
#
#       yield_kgs  new_latitude  new_longitude  new_altitude  new_accuracy
# 187       5.100     10.627515      12.100970        614.62          3.90
# 1700     30.230     11.897669       8.862787        435.07          4.14
# 2213      4.825     11.137769       9.721645        434.40          4.75
# 1771      1.440      9.235910      11.273407        114.90          3.42
# 1192     17.280     10.494448      10.437173        377.10          3.70
# 2221     11.180     11.627517      10.548392        387.40          3.90
# 845       5.875      9.292355       5.856010         50.40          3.64
# 402       5.660      9.745178       9.550646        631.10          4.95

# %%
#Assign new name to the data
wheat = cleaned_focused_data

# %% [markdown]
# ## Univariate Exploration
#
# > **What is the distribution the yields?**

# %%
#We define the function to add plotting information xlabel, ylabel and title
def plot_info(xlab,ylab,title):
    #Add plot title
    plt.title(title,fontweight = 'bold')
    #Add the x label
    plt.xlabel(xlab,fontweight = 'bold')
    #add the y label
    plt.ylabel(ylab,fontweight = 'bold')
    
#We define a function to customize plot area size    
def plotarea_size(width,length):
    #Define plot area size
    plt.figure(figsize=[width,length])

# %%
#define the size of bins
binsize = 1
bins = np.arange(0, wheat['yield_kgs'].max()+binsize, binsize)
yieldkgs = wheat['yield_kgs']
#Define plot area
plotarea_size(15,5)
#Plot histogram
plt.hist( x = yieldkgs, bins = bins)
#Add plot information
plot_info('Yield (Kg)','Frequeicies','A histogram to display the distribution of the yields')
#View plot
plt.show()

# %% [markdown]
# ## Observation:
#
# > There are outliers in the distribution of the yields data. This will require an exploration to the outliers.

# %%
# we drop missing values of the yields column in order to analyze the outliers
outlier_analysis = cleaned_focused_data['yield_kgs'].dropna()
outlier_analysis
# Out:
# 0       10.560697
# 1        9.390000
# 2        5.410000
# 3        4.705000
# 4        6.290000
#           ...
# 2351    11.805000
# 2352     8.865000
# 2353    13.340000
# 2354     9.040000
# 2355    11.870000
# Name: yield_kgs, Length: 2126, dtype: float64

# %%
#We define plot area size
plotarea_size(10,5)
#plot a box plot
sns.boxplot(x=outlier_analysis)
#Add plotting information
plot_info('Yield (Kg)','','A box plot to analyze outliers')
#view plot
plt.show()

# %%
#We plot a distribution plot to analyze the outliers
#Define plot area size
plotarea_size(10,5)
#plot distribution of the data
sns.distplot(outlier_analysis,bins = 30,kde = False)
#Add plotting information
plot_info('Yields (KG)','Frequencies','A distribution plot to analyze outliers')
#View plot
plt.show();

# %%
# We view the summary statistics of the yields data
outlier_analysis.describe()
# Out:
# count    2126.000000
# mean        8.378229
# std         6.780732
# min         0.100000
# 25%         3.521250
# 50%         6.670000
# 75%        11.443750
# max       104.200000
# Name: yield_kgs, dtype: float64

# %%
#We find the lower quartile
q1 = outlier_analysis.describe().quantile(0.25)
q1
# Out:
# 5.8828125

# %%
#We find the upper quartile
q3 = outlier_analysis.describe().quantile(0.75)
q3
# Out:
# 34.6328125

# %%
#We find the inter-quartile range
iqr = q3-q1
iqr
# Out:
# 28.75

# %%
upper_limit = q3+ 1.5*iqr
lower_limit = q1- 1.5*iqr

# %%
upper_limit
# Out:
# 77.7578125

# %%
lower_limit
# Out:
# -37.2421875

# %%
#We creatte the outier data frame in order to use filters to remove outliers
outlier_analysis = pd.DataFrame(outlier_analysis)
outlier_analysis = outlier_analysis.query('yield_kgs > -37.2421875 & yield_kgs < 77.7578125')
wheat = wheat.query('yield_kgs > -37.2421875 & yield_kgs < 77.7578125')

# %%
#We plot the distribution without outliers
#We define the bin size
binsize = 1
bins = np.arange(0, outlier_analysis['yield_kgs'].max()+binsize, binsize)
yieldkgs = outlier_analysis['yield_kgs']
#We define plot area
plotarea_size(15,5)
#Plot histogram
plt.hist( x = yieldkgs, bins = bins)
#Add plotting information
plot_info('Yield (Kg)','Frequeicies','A histogram to display the distribution of the yields without outliers')
#view plot
plt.show()

# %% [markdown]
# ## Observation
#
# > The data is positively skewed. It has a mean of 8.378kgs

# %%
wheat.box1_mode_of_planting.value_counts()
# Out:
# rows           1192
# broadcasted     933
# Name: box1_mode_of_planting, dtype: int64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ## Key analysis and Findings

# %% [markdown]
# > **Which mode of planting for box 1 has the highest total yields?**

# %%
#DEfine plot area
plotarea_size(8,8)
#Plot
plot = wheat.groupby('box1_mode_of_planting')['yield_kgs'].sum().plot.bar();
#Add plotting info
plot_info('Mode of planting','Total yields','A bar plot of the total yields from the box 1 modes of planting');
#rotate xlabels 35 degrees
plt.xticks(rotation = 35);

# %% [markdown]
# > **Observation:**
# The total yields are higher for broadcasted planting then for rows planting of wheat

# %% [markdown]
# > **Which planting method for box 1 has the highest average yield?**

# %%
#Define plot area
plotarea_size(8,8);
#create a plot
plot = wheat.groupby('box1_mode_of_planting')['yield_kgs'].mean().plot.bar();
#Add plotting information
plot_info('Mode of planting','Average yields','A bar plot of the average yields from the box 1 modes of planting');
# Rotate the plots 30 degrees
plt.xticks(rotation = 30);

# %% [markdown]
# > **Observation:**
#
# The average yields are still higher for broadcsted method over the rows method. The margin is also wider for average yields.

# %% [markdown]
# > **Which mode of planting in box 2 has the highest total yields?**

# %%
#Define the plot area
plotarea_size(8,8);
#Create a plot
plot = wheat.groupby('box2_mode_of_planting')['yield_kgs'].sum().plot.bar();
#Add plot info
plot_info('Mode of planting','Total yields','A bar plot of the total yields from the box 2 modes of planting');
#rotate the xlabels 30 degrees
plt.xticks(rotation = 30);

# %% [markdown]
# > **Observation:**
#
# The results are consstent with box 1 where the total yields are higher for broadcasted than for rows planting

# %% [markdown]
# > **Which mode of planting in box 2 has the highest average yields?**

# %%
#Define plot area
plotarea_size(8,8)
#Create plot
plot = wheat.groupby('box2_mode_of_planting')['yield_kgs'].mean().plot.bar();
#Add plot info
plot_info('Mode of planting','Average yields','A bar plot of the average yields from the box 2 modes of planting');
#rotate xlabels 30 degrees
plt.xticks(rotation = 30);

# %% [markdown]
# > **Observation:**
#
# The results are consistent with box 1 where broadcasted planting has a higher average, with the margin slightly wider than the totals.

# %%
wheat.box1_mode_of_planting.value_counts()
# Out:
# rows           1192
# broadcasted     933
# Name: box1_mode_of_planting, dtype: int64

# %%
wheat.box2_mode_of_planting.value_counts()
# Out:
# rows           1188
# broadcasted     937
# Name: box2_mode_of_planting, dtype: int64

# %% [markdown]
# > The difference in the totals and average is due to the larger number of farmers using rows planting than broadcasting method.

# %% [markdown]
# > **How does distance from water body affect the total wheat yields?**

# %%
#Define the plot area
plotarea_size(8,8)
#We create a plot
wheat.groupby('distance_to_water_body')['yield_kgs'].sum().plot.pie();
#We add plot info
plot_info('','','A pie chart of the total yields for different distances from water body')

# %% [markdown]
# > **Observation:**
#
# A huge part of the total yields comes from farmers who are 0-5KM from the water body.

# %% [markdown]
# > **How does distance from water body affect the average wheat yields?**

# %%
#Define the plot area size
plotarea_size(8,8);
# Create plot
wheat.groupby('distance_to_water_body')['yield_kgs'].mean().plot.pie();
# We add plotting information
plot_info('','','A pie chart of the average yields for different distances from water body');

# %% [markdown]
# > **Observation:**
#
# The average wheat yields are still higher for 0-5km from the water body. This time, the margin is smaller compared to the totals.

# %%
wheat.distance_to_water_body.value_counts()
# Out:
# 0-5KM             1756
# More_than_5_KM     369
# Name: distance_to_water_body, dtype: int64

# %% [markdown]
# > The difference in the total and the average yields margins is due to the fact that most farmers are within 0-5km from a water body

# %% [markdown]
# > **How does altitude affect the yields?**

# %%
#We define the plot area
plotarea_size(15,10);
#we create a plot
wheat.plot.scatter(x = 'new_altitude',y='yield_kgs',figsize = (15,10), color = 'green');
#We add plot information
plot_info('Altitude (ASL)','Yield (kgs)','A scatterplot of the yields for the different altitude levels');

# %% [markdown]
# > **Observation:**
#
# The wheat yields are highest around 500M ASL. The crop does well in altitudes of between 0M and 900M ASL

# %% [markdown]
# > **Which farmer state districts have the highest total yields?**

# %%
#We create the plot
wheat.groupby('farmer_state_district')['yield_kgs'].sum().sort_values(ascending=False).plot.bar(figsize = (15,8));
#We add plotting information
plot_info('Farmer State District','Yield (kgs)','A bar plot of the total yields for different state districts')
#We rotate the x labels 30 degrees
plt.xticks(rotation = 30);

# %% [markdown]
# > **Observation:**
#
# Bauchi has the highest total yields while Abia has the lowest total yields.

# %% [markdown]
# > **Which state district has the highest average yields?**

# %%
# We create a plot
wheat.groupby('farmer_state_district')['yield_kgs'].mean().sort_values(ascending=False).plot.bar(figsize = (15,8));
#We add plot information
plot_info('Farmer State District','Yield (kgs)','A bar plot of the total yields for different state districts')
#We rotate the x labels 30 degrees.
plt.xticks(rotation = 30);

# %% [markdown]
# > **Observation:**
#
# On the average yields, Kaduna has the highest yields, while Zamfara has the lowest

# %%
wheat.farmer_in_list_or_control.value_counts()
# Out:
# farmer_listed     1549
# control_farmer     576
# Name: farmer_in_list_or_control, dtype: int64

# %% [markdown]
# > **How does the farmer list/control status affect yield?**

# %%
#We define the plot area size
plotarea_size(8,8)
#We create a plot
wheat.groupby('farmer_in_list_or_control')['yield_kgs'].mean().plot.bar(figsize = (10,5));
#We add plotting information
plot_info('Status','Yield (kgs)','A barplot of farmer list/control status to display effect on yield');
#We rotate the x labels
plt.xticks(rotation = 30);

# %% [markdown]
# > **Observation:**
#
# Listed farmers have slightly higher average yields compared to control farmers

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# > **How does farmer list/control status affect the yield given a broadcasting method?**

# %%
# We create the catplot
sns.catplot(
    data=wheat, x='farmer_in_list_or_control', y="yield_kgs", hue="box1_mode_of_planting",
    kind="bar", height=6, aspect=1,color='grey'
);
# We add plotting information
plot_info('Farmer in list or control', 'Yield (Kg)','A catplot of how losting status and mode of planting affect yields')

# %% [markdown]
# > **Observation:**
#
# Farmers who are listed and use broadcasted planting are have higher yields than control farmers who use broadcast planting.
# Farmers who are listed and use rows have less yields compared to control farmers who use row planting

# %% [markdown]
# > **How does irrigation and distance to water body affect yield?**

# %%
#We create a catplot for the data
sns.catplot(
    data=wheat, x='field_irrigated', y="yield_kgs", hue="distance_to_water_body",color='grey',
    kind="bar", height=6, aspect=1,
);
#We add plotting information
plot_info('Fields irrigated?','Yield (Kg)','A catplot representing effects of irrigation and water body closeness to yield')

# %% [markdown]
# > **Observation:**
#
# Irrigations in areas 0-5km to water body lead to reduced yields, while irrigations around areas more than 5km from water bodies lead to increased yield.

# %%
#We create the plot
districtplot =sns.catplot( data=wheat, x='intercropping', y="yield_kgs",
            hue="box1_mode_of_planting", kind="bar", height= 6, aspect=1.3, color = 'black')
#We rotate the xlabel
districtplot.set_xticklabels(rotation=75)
# We add plotting information
plot_info('Intercropping status','Yield (kgs)','A catplot to show effects of intercropping and mode of planting on yields')

# %% [markdown]
# > **Observation:**
#
# When crops are planted solo, broadcasting method procuces higher yields than rows method, with a small margin.
# When crops are intercropped, briadcast method significantly increases the yield, with a higher margin compared to rows method

# %% [markdown]
# ##  How are the plantations distributed on a map?

# %%
#We create a spartial dataframe
spartial_data = cleaned_focused_data
spartial_data.sample(8)
# Out:
#                                    case_id client_name distance_to_water_body  \
# 1879  76710712-42ab-4624-9669-647de5ab2001           A                  0-5KM
# 1875  2e9bc3bc-a955-4d10-a069-9a5217cbb867           A                  0-5KM
# 985   4cbbd6bf-79de-4d31-8c19-182cf0654b96           A                  0-5KM
# 2349  ae1d9de9-36d2-4069-8466-6e38834ed995           A         More_than_5_KM
# 411   736bb1f2-2f76-4632-9fac-10f6c7686d0b           A                  0-5KM
# 73    0caa4976-be26-4a5f-9825-55efb1b9467c           A                  0-5KM
# 96    9cda4f3c-e363-4b41-afd5-d76a8704f1e8           A                  0-5KM
# 2340  89890798-3828-48a7-bfc1-e1ff6bcc5b8c           A         More_than_5_KM
#
#      insured_crop farmer_state_district farmer_in_list_or_control  \
# 1879        wheat                Bauchi             farmer_listed
# 1875        wheat                Bauchi             farmer_listed
# 985         wheat                 Niger             farmer_listed
# 2349        wheat                Bauchi             farmer_listed
# 411         wheat                 Gombe             farmer_listed
# 73          wheat                 Niger             farmer_listed
# 96          wheat               Katsina            control_farmer
# 2340        wheat                Bauchi             farmer_listed
#
#       farmer_verified field_irrigated intercropping  \
# 1879  farmer_verified             yes            no
# 1875  farmer_verified             yes            no
# 985   farmer_verified              no            no
# 2349  farmer_verified             yes            no
# 411   farmer_verified             yes            no
# 73    farmer_verified             yes           yes
# 96    farmer_verified             yes            no
# 2340  farmer_verified              no            no
#
#      crops_kept_in_separate_bags box1_mode_of_planting box2_mode_of_planting  \
# 1879                         yes           broadcasted           broadcasted
# 1875                         yes                  rows                  rows
# 985                          NaN                  rows                  rows
# 2349                         yes           broadcasted           broadcasted
# 411                          yes           broadcasted           broadcasted
# 73                           yes                  rows                  rows
# 96                           NaN           broadcasted           broadcasted
# 2340                         yes                  rows                  rows
#
#      type_of_irrigation_system other_crops_names name_of_enumerator  \
# 1879                  borehole               NaN             nig021
# 1875          rivers tube_well               NaN             nig029
# 985                        NaN               NaN             nig102
# 2349                 tube_well               NaN             nig022
# 411                   borehole               NaN             nig075
# 73                    borehole             maize             nig119
# 96                      rivers               NaN             nig187
# 2340                       NaN               NaN             nig023
#
#       yield_kgs  new_latitude  new_longitude  new_altitude  new_accuracy
# 1879      4.145     11.242907      10.495172        385.80          4.50
# 1875      9.465     10.292028       9.063212        781.50          3.76
# 985         NaN      9.531055       6.586216        211.50          4.72
# 2349     10.650     10.345600      10.038806        482.80          4.95
# 411      16.120     11.126098      11.440512        258.00          3.90
# 73        0.869      9.978459       6.748924        262.10          4.28
# 96          NaN     11.581986       7.199733        646.14          4.00
# 2340      9.045     10.815568       9.597328        488.60          3.90

# %%
# view the number of unique values 
spartial_data.nunique()
# Out:
# case_id                        2356
# client_name                       1
# distance_to_water_body            2
# insured_crop                      1
# farmer_state_district            15
# farmer_in_list_or_control         2
# farmer_verified                   1
# field_irrigated                   2
# intercropping                     2
# crops_kept_in_separate_bags       2
# box1_mode_of_planting             2
# box2_mode_of_planting             2
# type_of_irrigation_system        21
# other_crops_names                 4
# name_of_enumerator               78
# yield_kgs                      1713
# new_latitude                   2300
# new_longitude                  2302
# new_altitude                   1878
# new_accuracy                    425
# dtype: int64

# %%
#Count the distances from the water body
wheat.distance_to_water_body.value_counts()
# Out:
# 0-5KM             1756
# More_than_5_KM     369
# Name: distance_to_water_body, dtype: int64

# %%
# We check to find mussing values of thatitude column
spartial_data.query('new_latitude.isna()')
# Out:
# Empty DataFrame
# Columns: [case_id, client_name, distance_to_water_body, insured_crop, farmer_state_district, farmer_in_list_or_control, farmer_verified, field_irrigated, intercropping, crops_kept_in_separate_bags, box1_mode_of_planting, box2_mode_of_planting, type_of_irrigation_system, other_crops_names, name_of_enumerator, yield_kgs, new_latitude, new_longitude, new_altitude, new_accuracy]
# Index: []

# %%
#We import the map package
import folium
#Define the center location for the map
centre_location = [spartial_data.new_latitude.mean(),spartial_data.new_longitude.mean()]

# %%
#We create a map
map1 = folium.Map(location = centre_location,
                  tiles = 'https://{s}.basemaps.cartocdn.com/rastertiles/voyager_nolabels/{z}/{x}/{y}{r}.png',
                  attr='CartoDB.Voyager',zoom_start = 6, control_scale = True)

# %%
#We use a loop to fill the markers
for index, loc in spartial_data.iterrows():
    folium.CircleMarker([loc['new_latitude'],loc['new_longitude']], radius = 2, weight = 5, 
                        popup = loc['yield_kgs']).add_to(map1)
    
folium.LayerControl().add_to(map1)
#display the map
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06524fe489c6af7bb512c01e4f698d0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06524fe489c6af7bb512c01e4f698d0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_06524fe489c6af7bb512c01e4f698d0a = L.map(
#                 &quot;map_06524fe489c6af7bb512c01e4f698d0a&quot;,
#                 {
#                     center: [10.776192473457108, 8.705728790671335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_06524fe489c6af7bb512c01e4f698d0a);
#
#
#
#
#
#             var tile_layer_dfc05308d3280b1e4f63884b4ccd453e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager_nolabels/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;CartoDB.Voyager&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_06524fe489c6af7bb512c01e4f698d0a);
#
#
#             var circle_marker_454a3588f8f3c986625bef926f2f02cd = L.circleMarker(
#                 [11.3679741, 7.5680323],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_06524fe489c6af7bb512c01e4f698d0a);
#
#
#         var popup_9fbdf74c3836f9b709fd2333490f390c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8e0e29c303ea5b7b704ba231933fe3bd = $(`&lt;div id=&quot;html_8e0e29c303ea5b7b704ba231933fe3bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10.560696810827872&lt;/div&gt;`)[0];
#             popup_9fbdf74c3836f9b709fd2333490f390c.setContent(html_8e0e29c303ea5b7b704ba231933fe3bd);
#
#
#         circle_marker_454a3588f8f3c986625bef926f2f02cd.bindPopup(popup_9fbdf74c3836f9b709fd2333490f390c)
#         ;
#
#
#
#
#             var circle_marker_875d79de2d6ece44b2b02badda543c46 = L.circleMarker(
#                 [11.3679697, 7.5679833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_06524fe489c6af7bb512c01e4f698d0a);
#
#
#         var popup_b7c6cc963032f3331600815fa26a35b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_194cbf6360d9eaf1302b841c97ef44be = $(`&lt;div id=&quot;html_194cbf6360d9eaf1302b841c97ef44be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9.39&lt;/div&gt;`)[0];
#             popup_b7c6cc963032f3331600815fa26a35b1.setContent(html_194cbf6360d9eaf1302b841c97ef44be);
#
#
#         circle_marker_875d79de2d6ece44b2b02badda543c46.bindPopup(popup_b7c6cc963032f3331600815fa26a35b1)
#         ;
#
#
#
#
#             var circle_marker_60c553f1af2627a1eaa5dbca14793250 = L.circleMarker(
#                 [12.046592, 6.640337],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_06524fe489c6af7bb512c01e4f698d0a);
#
#
#         var popup_f088d45f8aeb1f1085ec1f0ec7cdebbc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_07e8335ea370737a9380bc15c17c1a0a = $(`&lt;div id=&quot;html_07e8335ea370737a9380bc15c17c1a0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5.41&lt;/div&gt;`)[0];
#             popup_f088d45f8aeb1f1085ec1f0ec7cdebbc.setContent(html_07e8335ea370737a9380bc15c17c1a0a);
#
#
#         circle_marker_60c553f1af2627a1eaa5dbca14793250.bindPopup(popup_f088d45f8aeb1f1085ec1f0ec7cdebbc)
#         ;
#
#
#
#
#             var circle_marker_1f3bfe047dde4a1a8b0de2561f837bb9 = L.circleMarker(
#                 [12.046592, 6.640337],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5

# %% [markdown]
# > **Observation:**
#
# The plantations are far from the ocean. However, they are aligned along rivers, with few of them close to lakes

# %%
# !jupyter nbconvert Part_II_slide_deck.ipynb --to slides --post serve --no-input --no-prompt
